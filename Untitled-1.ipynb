# %%
import tables
import tables
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import random

import fnmatch
import os
#import h5
import glob
import pickle
import sys
import argparse
import h5py
import os.path
import inspect
import json

from datetime import datetime
import time

from ctapipe.io import EventSource
from ctapipe import utils
from ctapipe.instrument.camera import CameraGeometry

from dl1_data_handler.reader import DL1DataReader
from dl1_data_handler.image_mapper import ImageMapper

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras import layers, models, callbacks, optimizers, regularizers
from tensorflow.keras.layers import Input, Concatenate, concatenate, Dense,Lambda,Reshape,Embedding, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, Flatten, Dropout, ConvLSTM2D, BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.models import Model, Sequential

class DataManager():
    """ Data class used to manage the HDF5 data files (simulations + Auger data).
        data_path: data_path of HDF5 file, (hint: use blosc compression to ensure adequate decompression speed,
        to mitigate training bottleneck due to a slow data pipeline)
        params:
            data_path = path to HDF5 datset
        optional params:
            stats: data statistics (stats.json - needed for scaling the dataset)
            tasks: list of tasks to be included (default: ['axis', 'core', 'energy', 'xmax'])
            generator_fn: generator function used for looping over data, generator function needs to have indices and
                          shuffle args.
            ad_map_fn: "advanced mapping function" the function used to map the final dataset. Here an additional
                       preprocessing can be implemented which is mapped during training on the
                       cpu (based on tf.data.experimental.map_and_batch)
    """

    def __init__(self, data_path, stats=None, tasks=['axis', 'impact', 'energy', 'classification']):
        ''' init of DataManager class, to manage simulated (CORSIKA/Offline) and measured dataset '''
        current_timestamp = int(time.time())
        np.random.seed(current_timestamp)
        self.data_path = data_path

    def open_ipython(self):
        from IPython import embed
        embed()

    @property
    def is_data(self):
        return self.type == "Data"

    @property
    def is_mc(self):
        return self.type == "MC"

    def get_h5_file(self):
        return h5py.File(self.data_path, "r")

    def walk_tree(self, details=True):
        """ Draw the tree of yout HDF5 file to see the hierachy of your dataset
            params: detail(activate details to see shapes and used compression ops, Default: True)
        """

        def walk(file, iter_str=''):
            try:
                keys = file.keys()
            except AttributeError:
                keys = []

            for key in keys:
                try:
                    if details:
                        file[key].dtype
                        print(iter_str + str(file[key]))
                    else:
                        print(iter_str + key)
                except AttributeError:
                    print(iter_str + key)
                    walk(file[key], "   " + iter_str)

        with h5py.File(self.data_path, "r") as file:
            print("filename:", file.filename)
            for key in file.keys():
                print(' - ' + key)
                walk(file[key], iter_str='   - ')

    def extract_info(self, path):
        with self.get_h5_file() as f:
            data = f[path]
            y = np.stack(data[:].tolist())

        return {k: y[:, i] for i, k in enumerate(data.dtype.names)}, dict(data.dtype.descr)

    def make_mc_data(self):
        return self.extract_info("simulation/event/subarray/shower")




def re_index_ct14(image):
    return image[5:, :, :]

def make_hess_geometry(file=None):
    # quick fix for dl1 data handler to circumvent to use ctapipe
    if file is None:
        with open(os.path.join(os.getcwd(), "geometry2d3.json")) as f: 
            attr_dict = json.load(f)

        data_ct14 = attr_dict["ct14_geo"]
        data_ct5 = attr_dict["ct5_geo"]
    else:
        data_ct14 = file["configuration/instrument/telescope/camera/geometry_0"][:].tolist()
        data_ct5 = file["configuration/instrument/telescope/camera/geometry_1"][:].tolist()

    class Geometry():
        def __init__(self, data):
            self.pix_id, self.pix_x, self.pix_y, self.pix_area = np.stack(data).T.astype(np.float32)
            self.pos_x = self.pix_x
            self.pos_y = self.pix_y

        def get_pix_pos(self):
            return np.column_stack([self.pix_x, self.pix_y]).T

    return Geometry(data_ct14), Geometry(data_ct5)

def get_current_path():
    filename = inspect.getframeinfo(inspect.currentframe()).filename
    return os.path.dirname(os.path.abspath(filename))

def rotate(pix_pos, rotation_angle=0):
    rotation_angle = rotation_angle * np.pi / 180.0
    rotation_matrix = np.matrix([[np.cos(rotation_angle), -np.sin(rotation_angle)],
                                [np.sin(rotation_angle), np.cos(rotation_angle)], ], dtype=float)

    pixel_positions = np.squeeze(np.asarray(np.dot(rotation_matrix, pix_pos)))
    return pixel_positions

def plot_image_2by2(train_data,event_nr,labels,string,dt):

    

    

    print("Plotting Example Event. Event Nr: ", event_nr)

    image1 = train_data[:,0,:,:] 
    image2 = train_data[:,1,:,:] 
    image3 = train_data[:,2,:,:] 
    image4 = train_data[:,3,:,:] 

    pltimage1 = image1[event_nr]
    pltimage2 = image2[event_nr]
    pltimage3 = image3[event_nr]
    pltimage4 = image4[event_nr]

    fig, ax = plt.subplots(2,2)

    im1 = ax[0,0].imshow(pltimage1[:,:,0], cmap='viridis',vmin=0)
    im2 = ax[0,1].imshow(pltimage2[:,:,0], cmap='viridis',vmin=0)
    im3 = ax[1,0].imshow(pltimage3[:,:,0], cmap='viridis',vmin=0)
    im4 = ax[1,1].imshow(pltimage4[:,:,0], cmap='viridis',vmin=0)

    cbar1 = fig.colorbar(im1, ax=ax[0, 0], orientation='vertical')
    cbar2 = fig.colorbar(im2, ax=ax[0, 1], orientation='vertical')
    cbar3 = fig.colorbar(im3, ax=ax[1, 0], orientation='vertical')
    cbar4 = fig.colorbar(im4, ax=ax[1, 1], orientation='vertical')


    label1 = labels[event_nr].ravel()[0]
    label2 = labels[event_nr].ravel()[1]
    label3 = labels[event_nr].ravel()[2]
    label4 = labels[event_nr].ravel()[3]

    str_label1 = '{}'.format(label1)
    str_label2 = '{}'.format(label2)
    str_label3 = '{}'.format(label3)
    str_label4 = '{}'.format(label4)

    ax[0, 0].text(0.05, 0.95, str_label1, transform=ax[0, 0].transAxes, color='white', fontsize=12, ha='center', va='center', bbox=dict(facecolor='black', alpha=0.7))
    ax[0, 1].text(0.05, 0.95, str_label2, transform=ax[0, 1].transAxes, color='white', fontsize=12, ha='center', va='center', bbox=dict(facecolor='black', alpha=0.7))
    ax[1, 0].text(0.05, 0.95, str_label3, transform=ax[1, 0].transAxes, color='white', fontsize=12, ha='center', va='center', bbox=dict(facecolor='black', alpha=0.7))
    ax[1, 1].text(0.05, 0.95, str_label4, transform=ax[1, 1].transAxes, color='white', fontsize=12, ha='center', va='center', bbox=dict(facecolor='black', alpha=0.7))
    plt.show()

    print("Min. and Max. Value for Image 1: ", np.min(pltimage1), " - " , np.max(pltimage1) , ". Sum: ", np.sum(pltimage1))
    print("Min. and Max. Value for Image 2: ", np.min(pltimage2), " - " , np.max(pltimage2), ". Sum: ", np.sum(pltimage2))
    print("Min. and Max. Value for Image 3: ", np.min(pltimage3), " - " , np.max(pltimage3), ". Sum: ", np.sum(pltimage3))
    print("Min. and Max. Value for Image 4: ", np.min(pltimage4), " - " , np.max(pltimage4), ". Sum: ", np.sum(pltimage4))

    #str_evnr = '{}'.format(event_nr)
    #name = "Test_images/Test_figure_evnr_" + str_evnr + "_" + string + "_" + dt + ".png"
    #fig.savefig(name)

print("Functions Defined.")

'''
parser = argparse.ArgumentParser()
parser.add_argument("-e", "--epochs", type=int)
parser.add_argument("-b", "--batch_size", type=int)
parser.add_argument("-r", "--rate", type=float)
parser.add_argument("-reg", "--regulization", type=float)
parser.add_argument("-t", "--threshold", type=float)
parser.add_argument("-c", "--cut", type=int)
parser.add_argument("-ne", "--numevents", type=int)
parser.add_argument("-ft","--fusiontype",type=str,default="latefc")
parser.add_argument("-n","--normalize",type=str,default="nonorm")
parser.add_argument("-loc","--location",type=str,default="alex")
parser.add_argument("-transfer","--transfer",type=str,default="no")
parser.add_argument("-base","--base",type=str,default='moda')

args = parser.parse_args()
num_epochs = args.epochs
batch_size = args.batch_size
rate = args.rate
reg = args.regulization
sum_threshold = args.threshold
cut_nonzero = args.cut
num_events = args.numevents
fusiontype = args.fusiontype
normalize = args.normalize
location = args.location
transfer = args.transfer
base = args.base
'''

location = 'local'
num_events = 2000
batch_size = 32
rate = 0.1
reg = 0.00001
sum_threshold = 60
cut_nonzero = 3


# Define the appendix to the file, for being able to specify some general changes in the model structure and trace back the changes when comparing the results of t´different models
fnr = "CustomResNet" 

current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y-%m-%d_%H-%M")
print("Date-Time: ", formatted_datetime)

#num_events = 1000
amount = int(num_events * 2)

if location == 'local':
    filePath_gamma="../../../mnt/c/Users/hanne/Desktop/Studium Physik/ECAP_HiWi_CNN/ECAP_HiWi_WorkingDirectory/phase2d3_timeinfo_gamma_diffuse_hybrid_preselect_20deg_0deg.h5"
    filePath_proton="../../../mnt/c/Users/hanne/Desktop/Studium Physik/ECAP_HiWi_CNN/ECAP_HiWi_WorkingDirectory/phase2d3_timeinfo_proton_hybrid_preselect_20deg_0deg.h5"
elif location == 'alex':    
    filePath_gamma = "../../../../wecapstor1/caph/mppi111h/new_sims/dnn/gamma_diffuse_noZBDT_noLocDist_hybrid_v2.h5"
    filePath_proton="../../../../wecapstor1/caph/mppi111h/new_sims/dnn/proton_noZBDT_noLocDist_hybrid_v2.h5"
else: print("Wrong location specified!")

dm_gamma = DataManager(filePath_gamma)
f_g = dm_gamma.get_h5_file()

if num_events >= len(f_g["dl1/event/telescope/images/tel_001"][:]) : num_events = len(f_g["dl1/event/telescope/images/tel_001"][:]) - 2
if amount >= len(f_g["dl1/event/telescope/images/tel_001"][:]) : amount = len(f_g["dl1/event/telescope/images/tel_001"][:]) - 1

tel1g_raw = f_g["dl1/event/telescope/images/tel_001"][0:amount]
tel2g_raw = f_g["dl1/event/telescope/images/tel_002"][0:amount]
tel3g_raw = f_g["dl1/event/telescope/images/tel_003"][0:amount]
tel4g_raw = f_g["dl1/event/telescope/images/tel_004"][0:amount]
#tel5g_raw = f_g["dl1/event/telescope/images/tel_005"][0:amount]

print("Successfully opened gamma data!")

labelsg = np.stack([data[2] for data in tel1g_raw])
labelsg_ones = np.ones_like(labelsg)

f_g.close()

dm_proton = DataManager(filePath_proton)
f_p = dm_proton.get_h5_file()

tel1p_raw = f_p["dl1/event/telescope/images/tel_001"][0:amount]
tel2p_raw = f_p["dl1/event/telescope/images/tel_002"][0:amount]
tel3p_raw = f_p["dl1/event/telescope/images/tel_003"][0:amount]
tel4p_raw = f_p["dl1/event/telescope/images/tel_004"][0:amount]
#tel5p_raw = f_p["dl1/event/telescope/images/tel_005"][0:amount]

print("Successfully opened proton data!")

labelsp = np.stack([data[2] for data in tel1p_raw])
labelsp_zeros = np.zeros_like(labelsp)

tel1 = np.concatenate((tel1g_raw,tel1p_raw),axis=0)
tel2 = np.concatenate((tel2g_raw,tel2p_raw),axis=0)
tel3 = np.concatenate((tel3g_raw,tel3p_raw),axis=0)
tel4 = np.concatenate((tel4g_raw,tel4p_raw),axis=0)
#tel5 = np.concatenate((tel5g_raw,tel5p_raw),axis=0)
labels = np.concatenate((labelsg_ones,labelsp_zeros),axis=0)

del tel1g_raw
del tel2g_raw
del tel3g_raw
del tel4g_raw

del tel1p_raw
del tel2p_raw
del tel3p_raw
del tel4p_raw

f_p.close()

del labelsp
del labelsg
del labelsp_zeros
del labelsg_ones

print("Shape of Tel1: ",np.shape(tel1))
print("Shape of Tel2: ",np.shape(tel2))
print("Shape of Tel3: ",np.shape(tel3))
print("Shape of Tel4: ",np.shape(tel4))
#print("Shape of Tel5: ",np.shape(tel5))
print("Shape of Labels: ",np.shape(labels))
print("Labels: ",labels)

geo_ct14, geo_ct5 = make_hess_geometry()
print(os.getcwd())
ct_14_mapper = ImageMapper(camera_types=["HESS-I"], pixel_positions={"HESS-I": rotate(geo_ct14.get_pix_pos())}, mapping_method={"HESS-I": "axial_addressing"})
#ct_5_mapper = ImageMapper(camera_types=["HESS-II"], pixel_positions={"HESS-II": rotate(geo_ct5.get_pix_pos())}, mapping_method={"HESS-II": "axial_addressing"})

mapped_images_1 = np.empty((num_events, 41,41,1))
mapped_images_2 = np.empty((num_events, 41,41,1))
mapped_images_3 = np.empty((num_events, 41,41,1))
mapped_images_4 = np.empty((num_events, 41,41,1))
#mapped_images_4 = np.empty((num_events, 41,41,1))
mapped_labels = np.empty(num_events)

length = num_events
max_value = len(tel1)
random_list = np.random.randint(max_value, size=length)
image_nr = 0

print(random_list[0:10])

cut_nonzero = 3
threshold_value = 0.0001  # Adjust this threshold value as needed

print("Start Mapping...")
for event_nr in random_list:


    
    image_1 = ct_14_mapper.map_image(tel1[event_nr][3][:, np.newaxis], 'HESS-I')
    image_2 = ct_14_mapper.map_image(tel2[event_nr][3][:, np.newaxis], 'HESS-I')
    image_3 = ct_14_mapper.map_image(tel3[event_nr][3][:, np.newaxis], 'HESS-I')   
    image_4 = ct_14_mapper.map_image(tel4[event_nr][3][:, np.newaxis], 'HESS-I')
    #image_5 = ct_5_mapper.map_image(tel5[event_nr][3][:, np.newaxis], 'HESS-II')   

    # Apply threshold on the sum of pixel values
    #sum_threshold = 60  # Adjust this value to your desired threshold
    sum_threshold = 60 #args.threshold

    if np.sum(image_1) < sum_threshold:
        image_1[:] = 0
    if np.sum(image_2) < sum_threshold:
        image_2[:] = 0
    if np.sum(image_3) < sum_threshold:
        image_3[:] = 0
    if np.sum(image_4) < sum_threshold:
        image_4[:] = 0
     
    # Set all pixels lower than the threshold value to zero
    image_1[image_1 < threshold_value] = 0
    image_2[image_2 < threshold_value] = 0
    image_3[image_3 < threshold_value] = 0
    image_4[image_4 < threshold_value] = 0
    #image_5[image_5 < threshold_value] = 0

    non_zero_count = sum(1 for img in [image_1, image_2, image_3, image_4] if np.sum(img) > 0)
    if non_zero_count >= cut_nonzero:
        mapped_images_1[image_nr] = image_1
        mapped_images_2[image_nr] = image_2
        mapped_images_3[image_nr] = image_3
        mapped_images_4[image_nr] = image_4
        #mapped_images_5[image_nr] = image_5
        mapped_labels[image_nr] = labels[event_nr]
        image_nr += 1
    
print("... Finished Mapping")

mapped_images = np.array([mapped_images_1,mapped_images_2,mapped_images_3,mapped_images_4]) #mapped_images_5])
print("Shape of mapped_images_1: ",np.shape(mapped_images_1))
print("Shape of mapped_images: ",np.shape(mapped_images))

del tel1
del tel2
del tel3
del tel4
del labels

del mapped_images_1
del mapped_images_2
del mapped_images_3
del mapped_images_4

# Reshape the final array, so it is present in the same way as MoDAII data
mapped_images = np.transpose(mapped_images, (1, 0, 2, 3, 4))
mapped_images = np.squeeze(mapped_images, axis=-1)
mapped_labels = mapped_labels[:,np.newaxis]

print("New shape of mapped_images: ",np.shape(mapped_images))
print("New shape of mapped_labels: ",np.shape(mapped_labels))


########################################################
# START WITH CNN STUFF


patience = 5
input_shape = (41, 41, 1)
pool_size = 2
kernel_size = 2

# some reshaping for the further use of the timing data in the CNN
mapped_images = mapped_images.reshape((*np.shape(mapped_images),1))

# overview about the important data array for later usage
print(np.shape(mapped_images)[0], " events with 4 images each are available \n")
print("Shape of 'event_labels': ",np.shape(mapped_labels))
print("Shape of 'peak_times': ",np.shape(mapped_images),"\n")

# split into random training data (80%) and test data (20%)
train_data = []
test_data = []
train_labels = []
test_labels = [] 

#data_dummy = mapped_images

random_selection = np.random.rand(np.shape(mapped_images)[0]) <= 0.8


train_data.append(mapped_images[random_selection])
test_data.append(mapped_images[~random_selection])
train_labels.append(mapped_labels[random_selection])
test_labels.append(mapped_labels[~random_selection])

#mapped_images = data_dummy
#del data_dummy

print(random_selection[0:10])

# free some memory space
del mapped_images
del mapped_labels

# convert to numpy array and reshape 
train_data = np.array(train_data)
train_data = train_data.reshape(np.shape(train_data[0]))
test_data = np.array(test_data)
test_data = test_data.reshape(np.shape(test_data[0]))

train_labels = np.array(train_labels)
train_labels = train_labels.reshape(np.shape(train_labels[0]))
test_labels = np.array(test_labels)
test_labels = test_labels.reshape(np.shape(test_labels[0]))

train_labels_multishape = np.zeros_like(train_data)
test_labels_multishape = np.zeros_like(test_data)

len_train = np.shape(train_data)[0]
len_test = np.shape(test_data)[0]

for i in range(0,len_train):
    train_labels_multishape[i,:,:,:] = train_labels[i]

for k in range(0,len_test):
    test_labels_multishape[k,:,:,:] = test_labels[k]

# overvew about the splitting into training and test data
print("Split into Training and Test Data")
print("Train data shape:", np.shape(train_data) , "-->",round(100*len_train/(len_train+len_test),2),"%")
print("Test data shape:", np.shape(test_data), "-->",round(100*len_test/(len_train+len_test),2), "%")
print("Train labels shape:", np.shape(train_labels))
print("Test labels shape:", np.shape(test_labels))

mean_values = np.mean(train_data,axis=(2,3))
max_values = np.amax(train_data,axis=(2,3))

mean = np.mean(mean_values)
max = np.max(max_values)

def preprocess_data(train_data, train_labels, threshold=0.000001):
    # Get the dimensions of the input data
    num_events, num_views, height, width, channels = train_data.shape
    
    # Reshape train_data into a single array with shape (num_events * num_views, height, width, channels)
    reshaped_data = train_data.reshape(-1, height, width, channels)
    reshaped_labels = np.repeat(train_labels,4,axis=0)


    # Compute the sum of pixel values along the last axis (assuming your images are grayscale)
    pixel_sums = np.sum(reshaped_data, axis=(1, 2, 3))
    
    # Find indices of images with sums greater than or equal to the threshold
    valid_indices = np.where(pixel_sums >= threshold)
    
    # Filter the reshaped data based on valid_indices
    filtered_data = reshaped_data[valid_indices]
    
    # Reshape train_labels to match the reshaped data
    filtered_labels = reshaped_labels[valid_indices]

    combined_data_labels = list(zip(filtered_data, filtered_labels))

    # Shuffle the combined array
    np.random.shuffle(combined_data_labels)

    # Split the shuffled array back into filtered_data and filtered_labels
    shuffled_data, shuffled_labels = zip(*combined_data_labels)

    # Convert them back to NumPy arrays
    shuffled_data = np.array(shuffled_data)
    shuffled_labels = np.array(shuffled_labels)

    return shuffled_data, shuffled_labels

# Example usage:
# filtered_train_data, filtered_train_labels = preprocess_data(train_data, train_labels, threshold=60)
#This will reshape train_labels to match the reshaped train_data so that each image has the label assigned to the event it belongs to.


filtered_data,filtered_labels = preprocess_data(train_data,train_labels)
filtered_test_data,filtered_test_labels = preprocess_data(test_data,test_labels)

print(np.shape(filtered_data))
print(np.shape(filtered_labels))

plot_image_2by2(train_data,4,train_labels_multishape,string="train",dt=formatted_datetime)
#plot_image_2by2(train_data,10,train_labels_multishape,string="train",dt=formatted_datetime)
#plot_image_2by2(train_data,14,train_labels_multishape,string="train",dt=formatted_datetime)
#plot_image_2by2(train_data,11,train_labels_multishape,string="train",dt=formatted_datetime)

plot_image_2by2(test_data,4,test_labels_multishape,string="test",dt=formatted_datetime)
#plot_image_2by2(test_data,10,test_labels_multishape,string="test",dt=formatted_datetime)
#plot_image_2by2(test_data,14,test_labels_multishape,string="test",dt=formatted_datetime)
#plot_image_2by2(test_data,11,test_labels_multishape,string="test",dt=formatted_datetime)
# Out:
# Functions Defined.
# Date-Time:  2023-11-17_14-04
# Successfully opened gamma data!
# Successfully opened proton data!
# Shape of Tel1:  (8000,)
# Shape of Tel2:  (8000,)
# Shape of Tel3:  (8000,)
# Shape of Tel4:  (8000,)
# Shape of Labels:  (8000,)
# Labels:  [1 1 1 ... 0 0 0]
# /home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory
# [1245 5316 2006 4045 1766 6890 3604 6683 4335 3860]
# Start Mapping...
# ... Finished Mapping
# Shape of mapped_images_1:  (2000, 41, 41, 1)
# Shape of mapped_images:  (4, 2000, 41, 41, 1)
# New shape of mapped_images:  (2000, 4, 41, 41)
# New shape of mapped_labels:  (2000, 1)
# 2000  events with 4 images each are available
#
# Shape of 'event_labels':  (2000, 1)
# Shape of 'peak_times':  (2000, 4, 41, 41, 1)
#
# [ True  True False  True  True  True False  True False False]
# Split into Training and Test Data
# Train data shape: (1594, 4, 41, 41, 1) --> 79.7 %
# Test data shape: (406, 4, 41, 41, 1) --> 20.3 %
# Train labels shape: (1594, 1)
# Test labels shape: (406, 1)
# (3532, 41, 41, 1)
# (3532, 1)
# Plotting Example Event. Event Nr:  4
# Min. and Max. Value for Image 1:  0.0  -  42.92404556274414 . Sum:  385.40001952135935
# Min. and Max. Value for Image 2:  0.0  -  45.385765075683594 . Sum:  378.21210877550766
# Min. and Max. Value for Image 3:  0.0  -  22.724143981933594 . Sum:  176.13988884724677
# Min. and Max. Value for Image 4:  0.0  -  28.774240493774414 . Sum:  443.413433495909
# Plotting Example Event. Event Nr:  4
# Min. and Max. Value for Image 1:  0.0  -  90.022216796875 . Sum:  593.4361043416429
# Min. and Max. Value for Image 2:  0.0  -  21.0300350189209 . Sum:  267.79481595754623
# Min. and Max. Value for Image 3:  0.0  -  38.67747116088867 . Sum:  310.8182235066779
# Min. and Max. Value for Image 4:  0.0  -  164.666015625 . Sum:  1217.6426206799224

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, AveragePooling2D
from keras.models import Model

input_shape = (41, 41, 1)
reg = 0.00001

def print_layer_dimensions(model):
    for layer in model.layers:
        print(f"Layer: {layer.name}, Input Shape: {layer.input_shape}")
        print(f"Layer: {layer.name}, Output Shape: {layer.output_shape}")
    print("#########################################################")
        

def create_custom_resnet_early_fromb0(inputs,model_name, dynamic_input_shape=False):
    def inner_block(input, filters,outer_nr,inner_nr, strides=(1, 1), firstblock = False,):
        shortcut = input

        bname = model_name + outer_nr + inner_nr

        if input.shape[-1] != filters:
            input = Conv2D(filters, (1, 1), strides=strides, padding='same')(input)
            input = BatchNormalization()(input)    

        if firstblock == True: 
            xaname = bname + "_Conv1x1-A_firstblock"
            xa = Conv2D(filters // 4, (1, 1), strides=(2,2), padding='same',name=xaname)(input)
            shortcut = Conv2D(filters, (1, 1), strides=(2,2), padding='same')(shortcut)
            shortcut = BatchNormalization()(shortcut)
        else: 
            xaname = bname + "_Conv1x1-A"
            xa = Conv2D(filters // 4, (1, 1), strides=strides, padding='same',name=xaname)(input)

        xbname = bname + "_BatchNorm-A" 
        xb = BatchNormalization()(xa)
        xcname = bname + "_ReLU-A" 
        xc = Activation('relu',name=xcname)(xb)
        xdname = bname + "_Conv3x3-B" 
        xd = Conv2D(filters // 4, (3, 3), strides=strides, padding='same',name = xdname)(xc)
        xename = bname + "_BatchNorm-B"
        xe = BatchNormalization()(xd)
        xfname = bname + "_ReLU-B"
        xf = Activation('relu',name=xfname)(xe)
        xgname = bname +"_Conv1x1-C"
        xg = Conv2D(filters, (1, 1), strides=strides, padding='same',name=xgname)(xf)
        xhname = bname + "_BatchNorm-C"
        xh = BatchNormalization()(xg)

        xiname = bname + "_ResidualConnection"
        xi = Add()([xh, shortcut])
        xjname = bname + "_ReLU-Final"
        xj = Activation('relu',name=xjname)(xi)
        return xj
    
    def outer_block(input,num_filters,block_nr):
        x1 = inner_block(input,num_filters,block_nr,'_1',firstblock=True)
        x2 = inner_block(x1,num_filters,block_nr,'_2')
        x3 = inner_block(x2,num_filters,block_nr,'_3')
        return x3
    
    #if dynamic_input_shape:
    #    input_shape = inputs.shape.as_list()[1:]  # Get shape excluding batch size
    #    input_shape = tuple(input_shape)  # Convert to tuple
    #    inputs = Input(shape=input_shape)    
    #else: inputs = Input(shape=(None,11,11,1024))
    if dynamic_input_shape:
        if isinstance(inputs, list):
            input_shape = K.int_shape(inputs[0])[:]
            print(f"List input shape: {input_shape}")
        else:
            input_shape = K.int_shape(inputs)[:]
            print(f"Single input shape: {input_shape}")

        if len(input_shape) == 3:
            input_shape = (1,) + input_shape
            print(f"Updated input shape: {input_shape}")

    #inputs = Input(shape=input_shape) 

    b1 = outer_block(inputs,512,'B1')
    b2 = outer_block(b1,1024,'B2')
    b3 = outer_block(b2,2048,'B3')

    avgpool = Lambda(lambda x: K.mean(x, axis=(1, 2), keepdims=False))(b3)

    #avgpool = GlobalAveragePooling2D()(x)
    outputs = Dense(units=1024, activation='softmax')(avgpool)

    model = Model(inputs=inputs, outputs=outputs, name=model_name)
    print_layer_dimensions(model)
    return model

def create_custom_resnet(inputs, model_name,start_layer=-1,freeze=False, dynamic_input_shape=False ):

    def inner_block(input, filters,outer_nr,inner_nr, strides=(1, 1), firstblock = False,):
        shortcut = input

        bname = model_name + outer_nr + inner_nr

        if input.shape[-1] != filters:
            input = Conv2D(filters, (1, 1), strides=strides, padding='same')(input)
            input = BatchNormalization()(input)    

        if firstblock == True: 
            xaname = bname + "_Conv1x1-A_firstblock"
            xa = Conv2D(filters // 4, (1, 1), strides=(2,2), padding='same',name=xaname)(input)
            shortcut = Conv2D(filters, (1, 1), strides=(2,2), padding='same')(shortcut)
            shortcut = BatchNormalization()(shortcut)
        else: 
            xaname = bname + "_Conv1x1-A"
            xa = Conv2D(filters // 4, (1, 1), strides=strides, padding='same',name=xaname)(input)

        xbname = bname + "_BatchNorm-A" 
        xb = BatchNormalization()(xa)
        xcname = bname + "_ReLU-A" 
        xc = Activation('relu',name=xcname)(xb)
        xdname = bname + "_Conv3x3-B" 
        xd = Conv2D(filters // 4, (3, 3), strides=strides, padding='same',name = xdname)(xc)
        xename = bname + "_BatchNorm-B"
        xe = BatchNormalization()(xd)
        xfname = bname + "_ReLU-B"
        xf = Activation('relu',name=xfname)(xe)
        xgname = bname +"_Conv1x1-C"
        xg = Conv2D(filters, (1, 1), strides=strides, padding='same',name=xgname)(xf)
        xhname = bname + "_BatchNorm-C"
        xh = BatchNormalization()(xg)

        




        xiname = bname + "_ResidualConnection"
        xi = Add()([xh, shortcut])
        xjname = bname + "_ReLU-Final"
        xj = Activation('relu',name=xjname)(xi)
        return xj
    
    def outer_block(input,num_filters,block_nr):
        x1 = inner_block(input,num_filters,block_nr,'_1',firstblock=True)
        x2 = inner_block(x1,num_filters,block_nr,'_2')
        x3 = inner_block(x2,num_filters,block_nr,'_3')
        return x3

    if dynamic_input_shape:
        input_shape = inputs.shape.as_list()[1:]  # Get shape excluding batch size
        input_shape = tuple(input_shape)  # Convert to tuple
        inputs = Input(shape=input_shape)
        
    inputconv_name = model_name + "_InputConvolution"
    inputconv = Conv2D(64, (7, 7),strides = (2,2), padding='same',name=inputconv_name)(inputs)
    #maxpool = MaxPooling2D(strides=(2,2), padding='same')(inputconv)
    
    x = outer_block(inputconv, 1024,'B0')
        
    x = outer_block(x,512,'B1')
    x = outer_block(x,1024,'B2')
    x = outer_block(x,2048,'B3')
    #x = Flatten()(x)


    avgpool = Lambda(lambda x: K.mean(x, axis=(1, 2), keepdims=False))(x)
    avgpoolname = model_name + "_GlobalAvgPool"
    #avgpool = GlobalAveragePooling2D(kernel_size=(2,2),name=avgpoolname)(x)
    densename = model_name + "_Dense1024softmax"
    dense = Dense(units=1024, activation='softmax')(avgpool)
    model = Model(inputs=inputs, outputs=dense,name=model_name)

    if start_layer != -1:
        for _ in range(0,start_layer):
            model.layers.pop(0)

    if freeze:
        for layer in model.layers:
            layer.trainable = False

    print_layer_dimensions(model)
            
    return model

def create_single_model(model):
    inputs = model.input
    x = model.output
    x = Dropout(0.5)(x)
    #x = Flatten(x)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_single = Model(inputs,outputs)
    print_layer_dimensions(model_single)
    return model_single

def create_latefc_model(models,inputs):
    fusionlayer = concatenate([model.output for model in models])
    x = Dropout(0.5)(fusionlayer)
    #x = Flatten(x)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_multi = Model(inputs,outputs)
    print_layer_dimensions(model_multi)
    return model_multi

def create_latemax_model(models,inputs):
    fusionlayer = Lambda(lambda x: tf.reduce_max(x, axis=0), output_shape=input_shape)([model.output for model in models])
    x = Dropout(0.5)(fusionlayer)
    #x = Flatten(x)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_multi = Model(inputs,outputs)
    print_layer_dimensions(model_multi)
    return model_multi

from keras import backend as K

def create_earlymax_model(models,inputs,block):

    if block == 0:
        nn1_block_idx = 15
        nn2_block = 'b1'
    elif block == 1:
        nn1_block_idx = 28
        nn2_block = 'b2'
    elif block == 2:
        nn1_block_idx = 42
        nn2_block = 'b3'    
    elif block == 3:
        nn1_block_idx = 56
        nn2_block = 'avgpool'
    else: print('Choose from b0 to b3 please')

    for model in models:
        print(model.layers[nn1_block_idx].output.shape)

    fusionlayer = concatenate([model.layers[nn1_block_idx].output for model in models],axis=-1)
    print("Fusionlayer:" ,fusionlayer.shape)
    fusionlayer = MaxPooling2D(pool_size=(4,1))(fusionlayer)
    print("Fusionlayer:" ,fusionlayer.shape)
    #input_shape_earlymax = (None,11,11,1024)
    #fusionlayer = Lambda(lambda x: tf.reduce_max(x, axis=-1), output_shape=input_shape)(fusionlayer)
    #fusionlayer = MaxPooling3D(pool_size=(1, 1, 4),padding='same')(fusionlayer)

    
    #def max_along_last_axis(x):
    #    return tf.reduce_max(x, axis=-1, keepdims=False)

    # Apply the custom function using Lambda layer
    #fused_feature_map = Lambda(max_along_last_axis)(fusionlayer)
    
    
    secondpart_model = create_custom_resnet_early_fromb0(fusionlayer,model_name="CNN2")

    x = Dropout(0.5)(secondpart_model.output)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_multi = Model(inputs,outputs)
    print_layer_dimensions(model_multi)

    return model_multi
    




# For example:

# %%
input_1 = Input(shape=input_shape)
cnn_model_1 = create_custom_resnet(input_1,'Model1')
input_2 = Input(shape=input_shape)
cnn_model_2 = create_custom_resnet(input_2,'Model2')
input_3 = Input(shape=input_shape)
cnn_model_3 = create_custom_resnet(input_3,'Model3')
input_4 = Input(shape=input_shape)
cnn_model_4 = create_custom_resnet(input_4,'Model4')    

print("################################################################")

model_multi = create_earlymax_model([cnn_model_1, cnn_model_2, cnn_model_3, cnn_model_4],[input_1, input_2, input_3, input_4],block=0)
model_multi.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_multi.summary()
# Out:
# Layer: input_443, Input Shape: [(None, 41, 41, 1)]
# Layer: input_443, Output Shape: [(None, 41, 41, 1)]
# Layer: Model1_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model1_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_14508, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14508, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15271, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15271, Output Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15273, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15273, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15274, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15274, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14509, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14509, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15275, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15275, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15272, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15272, Output Shape: (None, 11, 11, 1024)
# Layer: add_4523, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4523, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15276, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15276, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15277, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15277, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15278, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15278, Output Shape: (None, 11, 11, 1024)
# Layer: add_4524, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4524, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15279, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15279, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15280, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15280, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15281, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15281, Output Shape: (None, 11, 11, 1024)
# Layer: add_4525, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4525, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14510, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14510, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15282, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15282, Output Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15284, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15284, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15285, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15285, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14511, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14511, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15286, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15286, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15283, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15283, Output Shape: (None, 6, 6, 512)
# Layer: add_4526, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4526, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15287, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15287, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15288, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15288, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15289, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15289, Output Shape: (None, 6, 6, 512)
# Layer: add_4527, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4527, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15290, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15290, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15291, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15291, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15292, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15292, Output Shape: (None, 6, 6, 512)
# Layer: add_4528, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4528, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14512, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14512, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15293, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15293, Output Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15295, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15295, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15296, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15296, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14513, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14513, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15297, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15297, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15294, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15294, Output Shape: (None, 3, 3, 1024)
# Layer: add_4529, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4529, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15298, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15298, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15299, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15299, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15300, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15300, Output Shape: (None, 3, 3, 1024)
# Layer: add_4530, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4530, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15301, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15301, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15302, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15302, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15303, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15303, Output Shape: (None, 3, 3, 1024)
# Layer: add_4531, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4531, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14514, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14514, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_15304, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_15304, Output Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15306, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15306, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15307, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15307, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_14515, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14515, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15308, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15308, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15305, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15305, Output Shape: (None, 2, 2, 2048)
# Layer: add_4532, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4532, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15309, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15309, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15310, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15310, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15311, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15311, Output Shape: (None, 2, 2, 2048)
# Layer: add_4533, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4533, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15312, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15312, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15313, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15313, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15314, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15314, Output Shape: (None, 2, 2, 2048)
# Layer: add_4534, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4534, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_204, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_204, Output Shape: (None, 2048)
# Layer: dense_435, Input Shape: (None, 2048)
# Layer: dense_435, Output Shape: (None, 1024)
# #########################################################
# Layer: input_444, Input Shape: [(None, 41, 41, 1)]
# Layer: input_444, Output Shape: [(None, 41, 41, 1)]
# Layer: Model2_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model2_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_14516, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14516, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15315, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15315, Output Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15317, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15317, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15318, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15318, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14517, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14517, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15319, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15319, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15316, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15316, Output Shape: (None, 11, 11, 1024)
# Layer: add_4535, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4535, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15320, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15320, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15321, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15321, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15322, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15322, Output Shape: (None, 11, 11, 1024)
# Layer: add_4536, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4536, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15323, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15323, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15324, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15324, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15325, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15325, Output Shape: (None, 11, 11, 1024)
# Layer: add_4537, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4537, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14518, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14518, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15326, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15326, Output Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15328, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15328, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15329, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15329, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14519, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14519, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15330, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15330, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15327, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15327, Output Shape: (None, 6, 6, 512)
# Layer: add_4538, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4538, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15331, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15331, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15332, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15332, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15333, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15333, Output Shape: (None, 6, 6, 512)
# Layer: add_4539, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4539, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15334, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15334, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15335, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15335, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15336, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15336, Output Shape: (None, 6, 6, 512)
# Layer: add_4540, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4540, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14520, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14520, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15337, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15337, Output Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15339, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15339, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15340, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15340, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14521, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14521, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15341, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15341, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15338, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15338, Output Shape: (None, 3, 3, 1024)
# Layer: add_4541, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4541, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15342, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15342, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15343, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15343, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15344, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15344, Output Shape: (None, 3, 3, 1024)
# Layer: add_4542, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4542, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15345, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15345, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15346, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15346, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15347, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15347, Output Shape: (None, 3, 3, 1024)
# Layer: add_4543, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4543, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14522, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14522, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_15348, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_15348, Output Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15350, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15350, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15351, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15351, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_14523, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14523, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15352, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15352, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15349, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15349, Output Shape: (None, 2, 2, 2048)
# Layer: add_4544, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4544, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15353, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15353, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15354, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15354, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15355, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15355, Output Shape: (None, 2, 2, 2048)
# Layer: add_4545, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4545, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15356, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15356, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15357, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_15357, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15358, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_15358, Output Shape: (None, 2, 2, 2048)
# Layer: add_4546, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4546, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_205, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_205, Output Shape: (None, 2048)
# Layer: dense_436, Input Shape: (None, 2048)
# Layer: dense_436, Output Shape: (None, 1024)
# #########################################################
# Layer: input_445, Input Shape: [(None, 41, 41, 1)]
# Layer: input_445, Output Shape: [(None, 41, 41, 1)]
# Layer: Model3_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model3_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_14524, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14524, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15359, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_15359, Output Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15361, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15361, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15362, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15362, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14525, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14525, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15363, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15363, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15360, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15360, Output Shape: (None, 11, 11, 1024)
# Layer: add_4547, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4547, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15364, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15364, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15365, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15365, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15366, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15366, Output Shape: (None, 11, 11, 1024)
# Layer: add_4548, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4548, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15367, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15367, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15368, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_15368, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15369, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_15369, Output Shape: (None, 11, 11, 1024)
# Layer: add_4549, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4549, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14526, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14526, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15370, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_15370, Output Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15372, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15372, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15373, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15373, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14527, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14527, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15374, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15374, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15371, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15371, Output Shape: (None, 6, 6, 512)
# Layer: add_4550, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4550, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15375, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15375, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15376, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15376, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15377, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15377, Output Shape: (None, 6, 6, 512)
# Layer: add_4551, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4551, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15378, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15378, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15379, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_15379, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15380, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_15380, Output Shape: (None, 6, 6, 512)
# Layer: add_4552, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4552, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14528, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14528, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15381, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_15381, Output Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15383, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15383, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15384, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15384, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14529, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14529, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15385, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15385, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15382, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15382, Output Shape: (None, 3, 3, 1024)
# Layer: add_4553, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4553, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15386, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15386, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15387, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15387, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15388, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15388, Output Shape: (None, 3, 3, 1024)
# Layer: add_4554, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4554, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15389, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15389, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15390, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_15390, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15391, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_15391, Output Shape: (None, 3, 3, 1024)
# Layer: add_4555, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4555, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14530, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14530, Output Shape: (None, 3, 3, 2048)
# ...
# Layer: CNN2B1_2_ReLU-A, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_ReLU-A, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_Conv3x3-B, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_Conv3x3-B, Output Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15453, Input Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15453, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_ReLU-B, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_ReLU-B, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_Conv1x1-C, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_2_Conv1x1-C, Output Shape: (None, 1, 6, 512)
# Layer: batch_normalization_15454, Input Shape: (None, 1, 6, 512)
# Layer: batch_normalization_15454, Output Shape: (None, 1, 6, 512)
# Layer: add_4572, Input Shape: [(None, 1, 6, 512), (None, 1, 6, 512)]
# Layer: add_4572, Output Shape: (None, 1, 6, 512)
# Layer: CNN2B1_2_ReLU-Final, Input Shape: (None, 1, 6, 512)
# Layer: CNN2B1_2_ReLU-Final, Output Shape: (None, 1, 6, 512)
# Layer: CNN2B1_3_Conv1x1-A, Input Shape: (None, 1, 6, 512)
# Layer: CNN2B1_3_Conv1x1-A, Output Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15455, Input Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15455, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_ReLU-A, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_ReLU-A, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_Conv3x3-B, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_Conv3x3-B, Output Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15456, Input Shape: (None, 1, 6, 128)
# Layer: batch_normalization_15456, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_ReLU-B, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_ReLU-B, Output Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_Conv1x1-C, Input Shape: (None, 1, 6, 128)
# Layer: CNN2B1_3_Conv1x1-C, Output Shape: (None, 1, 6, 512)
# Layer: batch_normalization_15457, Input Shape: (None, 1, 6, 512)
# Layer: batch_normalization_15457, Output Shape: (None, 1, 6, 512)
# Layer: add_4573, Input Shape: [(None, 1, 6, 512), (None, 1, 6, 512)]
# Layer: add_4573, Output Shape: (None, 1, 6, 512)
# Layer: CNN2B1_3_ReLU-Final, Input Shape: (None, 1, 6, 512)
# Layer: CNN2B1_3_ReLU-Final, Output Shape: (None, 1, 6, 512)
# Layer: conv2d_14542, Input Shape: (None, 1, 6, 512)
# Layer: conv2d_14542, Output Shape: (None, 1, 6, 1024)
# Layer: batch_normalization_15458, Input Shape: (None, 1, 6, 1024)
# Layer: batch_normalization_15458, Output Shape: (None, 1, 6, 1024)
# Layer: CNN2B2_1_Conv1x1-A_firstblock, Input Shape: (None, 1, 6, 1024)
# Layer: CNN2B2_1_Conv1x1-A_firstblock, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15460, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15460, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_ReLU-A, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_ReLU-A, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_Conv3x3-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_Conv3x3-B, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15461, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15461, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_ReLU-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_ReLU-B, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_Conv1x1-C, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_1_Conv1x1-C, Output Shape: (None, 1, 3, 1024)
# Layer: conv2d_14543, Input Shape: (None, 1, 6, 512)
# Layer: conv2d_14543, Output Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15462, Input Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15462, Output Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15459, Input Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15459, Output Shape: (None, 1, 3, 1024)
# Layer: add_4574, Input Shape: [(None, 1, 3, 1024), (None, 1, 3, 1024)]
# Layer: add_4574, Output Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_1_ReLU-Final, Input Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_1_ReLU-Final, Output Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_2_Conv1x1-A, Input Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_2_Conv1x1-A, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15463, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15463, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_ReLU-A, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_ReLU-A, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_Conv3x3-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_Conv3x3-B, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15464, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15464, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_ReLU-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_ReLU-B, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_Conv1x1-C, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_2_Conv1x1-C, Output Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15465, Input Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15465, Output Shape: (None, 1, 3, 1024)
# Layer: add_4575, Input Shape: [(None, 1, 3, 1024), (None, 1, 3, 1024)]
# Layer: add_4575, Output Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_2_ReLU-Final, Input Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_2_ReLU-Final, Output Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_3_Conv1x1-A, Input Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_3_Conv1x1-A, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15466, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15466, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_ReLU-A, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_ReLU-A, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_Conv3x3-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_Conv3x3-B, Output Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15467, Input Shape: (None, 1, 3, 256)
# Layer: batch_normalization_15467, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_ReLU-B, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_ReLU-B, Output Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_Conv1x1-C, Input Shape: (None, 1, 3, 256)
# Layer: CNN2B2_3_Conv1x1-C, Output Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15468, Input Shape: (None, 1, 3, 1024)
# Layer: batch_normalization_15468, Output Shape: (None, 1, 3, 1024)
# Layer: add_4576, Input Shape: [(None, 1, 3, 1024), (None, 1, 3, 1024)]
# Layer: add_4576, Output Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_3_ReLU-Final, Input Shape: (None, 1, 3, 1024)
# Layer: CNN2B2_3_ReLU-Final, Output Shape: (None, 1, 3, 1024)
# Layer: conv2d_14544, Input Shape: (None, 1, 3, 1024)
# Layer: conv2d_14544, Output Shape: (None, 1, 3, 2048)
# Layer: batch_normalization_15469, Input Shape: (None, 1, 3, 2048)
# Layer: batch_normalization_15469, Output Shape: (None, 1, 3, 2048)
# Layer: CNN2B3_1_Conv1x1-A_firstblock, Input Shape: (None, 1, 3, 2048)
# Layer: CNN2B3_1_Conv1x1-A_firstblock, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15471, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15471, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_ReLU-A, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_ReLU-A, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_Conv3x3-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_Conv3x3-B, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15472, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15472, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_ReLU-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_ReLU-B, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_Conv1x1-C, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_1_Conv1x1-C, Output Shape: (None, 1, 2, 2048)
# Layer: conv2d_14545, Input Shape: (None, 1, 3, 1024)
# Layer: conv2d_14545, Output Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15473, Input Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15473, Output Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15470, Input Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15470, Output Shape: (None, 1, 2, 2048)
# Layer: add_4577, Input Shape: [(None, 1, 2, 2048), (None, 1, 2, 2048)]
# Layer: add_4577, Output Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_1_ReLU-Final, Input Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_1_ReLU-Final, Output Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_2_Conv1x1-A, Input Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_2_Conv1x1-A, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15474, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15474, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_ReLU-A, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_ReLU-A, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_Conv3x3-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_Conv3x3-B, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15475, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15475, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_ReLU-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_ReLU-B, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_Conv1x1-C, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_2_Conv1x1-C, Output Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15476, Input Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15476, Output Shape: (None, 1, 2, 2048)
# Layer: add_4578, Input Shape: [(None, 1, 2, 2048), (None, 1, 2, 2048)]
# Layer: add_4578, Output Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_2_ReLU-Final, Input Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_2_ReLU-Final, Output Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_3_Conv1x1-A, Input Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_3_Conv1x1-A, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15477, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15477, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_ReLU-A, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_ReLU-A, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_Conv3x3-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_Conv3x3-B, Output Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15478, Input Shape: (None, 1, 2, 512)
# Layer: batch_normalization_15478, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_ReLU-B, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_ReLU-B, Output Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_Conv1x1-C, Input Shape: (None, 1, 2, 512)
# Layer: CNN2B3_3_Conv1x1-C, Output Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15479, Input Shape: (None, 1, 2, 2048)
# Layer: batch_normalization_15479, Output Shape: (None, 1, 2, 2048)
# Layer: add_4579, Input Shape: [(None, 1, 2, 2048), (None, 1, 2, 2048)]
# Layer: add_4579, Output Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_3_ReLU-Final, Input Shape: (None, 1, 2, 2048)
# Layer: CNN2B3_3_ReLU-Final, Output Shape: (None, 1, 2, 2048)
# Layer: lambda_208, Input Shape: (None, 1, 2, 2048)
# Layer: lambda_208, Output Shape: (None, 2048)
# Layer: dense_439, Input Shape: (None, 2048)
# Layer: dense_439, Output Shape: (None, 1024)
# #########################################################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> cnn_model_4 = create_custom_resnet(input_4,'Model4')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> print("################################################################")
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> model_multi = create_earlymax_model([cnn_model_1, cnn_model_2, cnn_model_3, cnn_model_4],[input_1, input_2, input_3, input_4],block=0)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> model_multi.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> model_multi.summary()
#
# /home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb Cell 3 line 2
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=246'>247</a> x = Dropout(0.5)(secondpart_model.output)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=247'>248</a> outputs = Dense(units=1, activation='sigmoid')(x)
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=248'>249</a> model_multi = Model(inputs,outputs)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=249'>250</a> print_layer_dimensions(model_multi)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=251'>252</a> return model_multi
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/keras/engine/functional.py:165, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     156     if not all(
#     157         [
#     158             functional_utils.is_input_keras_tensor(t)
#     159             for t in tf.nest.flatten(inputs)
#     160         ]
#     161     ):
#     162         inputs, outputs = functional_utils.clone_graph_nodes(
#     163             inputs, outputs
#     164         )
# --> 165 self._init_graph_network(inputs, outputs)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/keras/engine/functional.py:264, in Functional._init_graph_network(self, inputs, outputs)
#     261     self._input_coordinates.append((layer, node_index, tensor_index))
#     263 # Keep track of the network's nodes and layers.
# --> 264 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     265     self.inputs, self.outputs
#     266 )
#     267 self._network_nodes = nodes
#     268 self._nodes_by_depth = nodes_by_depth
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/keras/engine/functional.py:1128, in _map_graph_network(inputs, outputs)
#    1126 for x in tf.nest.flatten(node.keras_inputs):
#    1127     if id(x) not in computable_tensors:
# -> 1128         raise ValueError(
#    1129             f"Graph disconnected: cannot obtain value for "
#    1130             f'tensor {x} at layer "{layer.name}". '
#    1131             "The following previous layers were accessed "
#    1132             f"without issue: {layers_with_complete_input}"
#    1133         )
#    1134 for x in tf.nest.flatten(node.outputs):
#    1135     computable_tensors.add(id(x))
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(None, 2, 11, 4096), dtype=tf.float32, name=None), name='Placeholder:0', description="created by layer 'input_447'") at layer "conv2d_14540". The following previous layers were accessed without issue: []

# %%
num_epochs = 5
batch_size = 32

inputs = Input(shape=input_shape)
base_cnn = create_custom_resnet(inputs,'BaseCNN')
single_view_input = Input(shape=input_shape)
single_view_model = create_single_model(base_cnn)

single_view_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
single_view_model.summary()
#single_view_model.fit(filtered_data, filtered_labels, epochs=num_epochs, batch_size=batch_size,validation_data=(filtered_test_data,filtered_test_labels))
# Out:
# Layer: input_412, Input Shape: [(None, 41, 41, 1)]
# Layer: input_412, Output Shape: [(None, 41, 41, 1)]
# Layer: BaseCNN_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: BaseCNN_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_14283, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14283, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_14035, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_14035, Output Shape: (None, 21, 21, 1024)
# Layer: BaseCNNB0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: BaseCNNB0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14037, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14037, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14038, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14038, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14284, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14284, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14039, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14039, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14036, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14036, Output Shape: (None, 11, 11, 1024)
# Layer: add_4186, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4186, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14040, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14040, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14041, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14041, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14042, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14042, Output Shape: (None, 11, 11, 1024)
# Layer: add_4187, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4187, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14043, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14043, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14044, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14044, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14045, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14045, Output Shape: (None, 11, 11, 1024)
# Layer: add_4188, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4188, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14285, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14285, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_14046, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_14046, Output Shape: (None, 11, 11, 512)
# Layer: BaseCNNB1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: BaseCNNB1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14048, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14048, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14049, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14049, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14286, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14286, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14050, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14050, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14047, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14047, Output Shape: (None, 6, 6, 512)
# Layer: add_4189, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4189, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14051, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14051, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14052, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14052, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14053, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14053, Output Shape: (None, 6, 6, 512)
# Layer: add_4190, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4190, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14054, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14054, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14055, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14055, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14056, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14056, Output Shape: (None, 6, 6, 512)
# Layer: add_4191, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4191, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14287, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14287, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_14057, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_14057, Output Shape: (None, 6, 6, 1024)
# Layer: BaseCNNB2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: BaseCNNB2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14059, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14059, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14060, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14060, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14288, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14288, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14061, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14061, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14058, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14058, Output Shape: (None, 3, 3, 1024)
# Layer: add_4192, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4192, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14062, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14062, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14063, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14063, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14064, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14064, Output Shape: (None, 3, 3, 1024)
# Layer: add_4193, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4193, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14065, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14065, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14066, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14066, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14067, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14067, Output Shape: (None, 3, 3, 1024)
# Layer: add_4194, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4194, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14289, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14289, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_14068, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_14068, Output Shape: (None, 3, 3, 2048)
# Layer: BaseCNNB3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: BaseCNNB3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14070, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14070, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14071, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14071, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_14290, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14290, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14072, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14072, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14069, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14069, Output Shape: (None, 2, 2, 2048)
# Layer: add_4195, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4195, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14073, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14073, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14074, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14074, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14075, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14075, Output Shape: (None, 2, 2, 2048)
# Layer: add_4196, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4196, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14076, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14076, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14077, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14077, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14078, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14078, Output Shape: (None, 2, 2, 2048)
# Layer: add_4197, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4197, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_175, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_175, Output Shape: (None, 2048)
# Layer: dense_401, Input Shape: (None, 2048)
# Layer: dense_401, Output Shape: (None, 1024)
# #########################################################
# Layer: input_412, Input Shape: [(None, 41, 41, 1)]
# Layer: input_412, Output Shape: [(None, 41, 41, 1)]
# Layer: BaseCNN_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: BaseCNN_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_14283, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14283, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_14035, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_14035, Output Shape: (None, 21, 21, 1024)
# Layer: BaseCNNB0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: BaseCNNB0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14037, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14037, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14038, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14038, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14284, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_14284, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14039, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14039, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14036, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14036, Output Shape: (None, 11, 11, 1024)
# Layer: add_4186, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4186, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14040, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14040, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14041, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14041, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14042, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14042, Output Shape: (None, 11, 11, 1024)
# Layer: add_4187, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4187, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14043, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14043, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14044, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_14044, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: BaseCNNB0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14045, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_14045, Output Shape: (None, 11, 11, 1024)
# Layer: add_4188, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_4188, Output Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: BaseCNNB0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_14285, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14285, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_14046, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_14046, Output Shape: (None, 11, 11, 512)
# Layer: BaseCNNB1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: BaseCNNB1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14048, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14048, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14049, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14049, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14286, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_14286, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14050, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14050, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14047, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14047, Output Shape: (None, 6, 6, 512)
# Layer: add_4189, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4189, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14051, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14051, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14052, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14052, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14053, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14053, Output Shape: (None, 6, 6, 512)
# Layer: add_4190, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4190, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14054, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14054, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14055, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_14055, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: BaseCNNB1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14056, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_14056, Output Shape: (None, 6, 6, 512)
# Layer: add_4191, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_4191, Output Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: BaseCNNB1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_14287, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14287, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_14057, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_14057, Output Shape: (None, 6, 6, 1024)
# Layer: BaseCNNB2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: BaseCNNB2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14059, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14059, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14060, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14060, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14288, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_14288, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14061, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14061, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14058, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14058, Output Shape: (None, 3, 3, 1024)
# Layer: add_4192, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4192, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14062, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14062, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14063, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14063, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14064, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14064, Output Shape: (None, 3, 3, 1024)
# Layer: add_4193, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4193, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14065, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14065, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14066, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_14066, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: BaseCNNB2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14067, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_14067, Output Shape: (None, 3, 3, 1024)
# Layer: add_4194, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_4194, Output Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: BaseCNNB2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_14289, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14289, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_14068, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_14068, Output Shape: (None, 3, 3, 2048)
# Layer: BaseCNNB3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: BaseCNNB3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14070, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14070, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14071, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14071, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_14290, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_14290, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14072, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14072, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14069, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14069, Output Shape: (None, 2, 2, 2048)
# Layer: add_4195, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4195, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14073, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14073, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14074, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14074, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14075, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14075, Output Shape: (None, 2, 2, 2048)
# Layer: add_4196, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4196, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14076, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14076, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14077, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_14077, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: BaseCNNB3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14078, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_14078, Output Shape: (None, 2, 2, 2048)
# Layer: add_4197, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_4197, Output Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: BaseCNNB3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_175, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_175, Output Shape: (None, 2048)
# Layer: dense_401, Input Shape: (None, 2048)
# Layer: dense_401, Output Shape: (None, 1024)
# Layer: dropout_45, Input Shape: (None, 1024)
# Layer: dropout_45, Output Shape: (None, 1024)
# Layer: dense_402, Input Shape: (None, 1024)
# Layer: dense_402, Output Shape: (None, 1)
# #########################################################
# Model: "model_399"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_412 (InputLayer)         [(None, 41, 41, 1)]  0           []
#
#  BaseCNN_InputConvolution (Conv  (None, 21, 21, 64)  3200        ['input_412[0][0]']
#  2D)
#
#  conv2d_14283 (Conv2D)          (None, 21, 21, 1024  66560       ['BaseCNN_InputConvolution[0][0]'
#                                 )                                ]
#
#  batch_normalization_14035 (Bat  (None, 21, 21, 1024  4096       ['conv2d_14283[0][0]']
#  chNormalization)               )
#
#  BaseCNNB0_1_Conv1x1-A_firstblo  (None, 11, 11, 256)  262400     ['batch_normalization_14035[0][0]
#  ck (Conv2D)                                                     ']
#
#  batch_normalization_14037 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_1_Conv1x1-A_firstbloc
#  chNormalization)                                                k[0][0]']
#
#  BaseCNNB0_1_ReLU-A (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14037[0][0]
#  )                                                               ']
#
#  BaseCNNB0_1_Conv3x3-B (Conv2D)  (None, 11, 11, 256)  590080     ['BaseCNNB0_1_ReLU-A[0][0]']
#
#  batch_normalization_14038 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_1_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB0_1_ReLU-B (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14038[0][0]
#  )                                                               ']
#
#  BaseCNNB0_1_Conv1x1-C (Conv2D)  (None, 11, 11, 1024  263168     ['BaseCNNB0_1_ReLU-B[0][0]']
#                                 )
#
#  conv2d_14284 (Conv2D)          (None, 11, 11, 1024  66560       ['BaseCNN_InputConvolution[0][0]'
#                                 )                                ]
#
#  batch_normalization_14039 (Bat  (None, 11, 11, 1024  4096       ['BaseCNNB0_1_Conv1x1-C[0][0]']
#  chNormalization)               )
#
#  batch_normalization_14036 (Bat  (None, 11, 11, 1024  4096       ['conv2d_14284[0][0]']
#  chNormalization)               )
#
#  add_4186 (Add)                 (None, 11, 11, 1024  0           ['batch_normalization_14039[0][0]
#                                 )                                ',
#                                                                   'batch_normalization_14036[0][0]
#                                                                  ']
#
#  BaseCNNB0_1_ReLU-Final (Activa  (None, 11, 11, 1024  0          ['add_4186[0][0]']
#  tion)                          )
#
#  BaseCNNB0_2_Conv1x1-A (Conv2D)  (None, 11, 11, 256)  262400     ['BaseCNNB0_1_ReLU-Final[0][0]']
#
#  batch_normalization_14040 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_2_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB0_2_ReLU-A (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14040[0][0]
#  )                                                               ']
#
#  BaseCNNB0_2_Conv3x3-B (Conv2D)  (None, 11, 11, 256)  590080     ['BaseCNNB0_2_ReLU-A[0][0]']
#
#  batch_normalization_14041 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_2_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB0_2_ReLU-B (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14041[0][0]
#  )                                                               ']
#
#  BaseCNNB0_2_Conv1x1-C (Conv2D)  (None, 11, 11, 1024  263168     ['BaseCNNB0_2_ReLU-B[0][0]']
#                                 )
#
#  batch_normalization_14042 (Bat  (None, 11, 11, 1024  4096       ['BaseCNNB0_2_Conv1x1-C[0][0]']
#  chNormalization)               )
#
#  add_4187 (Add)                 (None, 11, 11, 1024  0           ['batch_normalization_14042[0][0]
#                                 )                                ',
#                                                                   'BaseCNNB0_1_ReLU-Final[0][0]']
#
#  BaseCNNB0_2_ReLU-Final (Activa  (None, 11, 11, 1024  0          ['add_4187[0][0]']
#  tion)                          )
#
#  BaseCNNB0_3_Conv1x1-A (Conv2D)  (None, 11, 11, 256)  262400     ['BaseCNNB0_2_ReLU-Final[0][0]']
#
#  batch_normalization_14043 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_3_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB0_3_ReLU-A (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14043[0][0]
#  )                                                               ']
#
#  BaseCNNB0_3_Conv3x3-B (Conv2D)  (None, 11, 11, 256)  590080     ['BaseCNNB0_3_ReLU-A[0][0]']
#
#  batch_normalization_14044 (Bat  (None, 11, 11, 256)  1024       ['BaseCNNB0_3_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB0_3_ReLU-B (Activation  (None, 11, 11, 256)  0          ['batch_normalization_14044[0][0]
#  )                                                               ']
#
#  BaseCNNB0_3_Conv1x1-C (Conv2D)  (None, 11, 11, 1024  263168     ['BaseCNNB0_3_ReLU-B[0][0]']
#                                 )
#
#  batch_normalization_14045 (Bat  (None, 11, 11, 1024  4096       ['BaseCNNB0_3_Conv1x1-C[0][0]']
#  chNormalization)               )
#
#  add_4188 (Add)                 (None, 11, 11, 1024  0           ['batch_normalization_14045[0][0]
#                                 )                                ',
#                                                                   'BaseCNNB0_2_ReLU-Final[0][0]']
#
#  BaseCNNB0_3_ReLU-Final (Activa  (None, 11, 11, 1024  0          ['add_4188[0][0]']
#  tion)                          )
#
#  conv2d_14285 (Conv2D)          (None, 11, 11, 512)  524800      ['BaseCNNB0_3_ReLU-Final[0][0]']
#
#  batch_normalization_14046 (Bat  (None, 11, 11, 512)  2048       ['conv2d_14285[0][0]']
#  chNormalization)
#
#  BaseCNNB1_1_Conv1x1-A_firstblo  (None, 6, 6, 128)   65664       ['batch_normalization_14046[0][0]
#  ck (Conv2D)                                                     ']
#
#  batch_normalization_14048 (Bat  (None, 6, 6, 128)   512         ['BaseCNNB1_1_Conv1x1-A_firstbloc
#  chNormalization)                                                k[0][0]']
#
#  BaseCNNB1_1_ReLU-A (Activation  (None, 6, 6, 128)   0           ['batch_normalization_14048[0][0]
#  )                                                               ']
#
#  BaseCNNB1_1_Conv3x3-B (Conv2D)  (None, 6, 6, 128)   147584      ['BaseCNNB1_1_ReLU-A[0][0]']
#
#  batch_normalization_14049 (Bat  (None, 6, 6, 128)   512         ['BaseCNNB1_1_Conv3x3-B[0][0]']
#  chNormalization)
# ...
#  batch_normalization_14062 (Bat  (None, 3, 3, 256)   1024        ['BaseCNNB2_2_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB2_2_ReLU-A (Activation  (None, 3, 3, 256)   0           ['batch_normalization_14062[0][0]
#  )                                                               ']
#
#  BaseCNNB2_2_Conv3x3-B (Conv2D)  (None, 3, 3, 256)   590080      ['BaseCNNB2_2_ReLU-A[0][0]']
#
#  batch_normalization_14063 (Bat  (None, 3, 3, 256)   1024        ['BaseCNNB2_2_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB2_2_ReLU-B (Activation  (None, 3, 3, 256)   0           ['batch_normalization_14063[0][0]
#  )                                                               ']
#
#  BaseCNNB2_2_Conv1x1-C (Conv2D)  (None, 3, 3, 1024)  263168      ['BaseCNNB2_2_ReLU-B[0][0]']
#
#  batch_normalization_14064 (Bat  (None, 3, 3, 1024)  4096        ['BaseCNNB2_2_Conv1x1-C[0][0]']
#  chNormalization)
#
#  add_4193 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_14064[0][0]
#                                                                  ',
#                                                                   'BaseCNNB2_1_ReLU-Final[0][0]']
#
#  BaseCNNB2_2_ReLU-Final (Activa  (None, 3, 3, 1024)  0           ['add_4193[0][0]']
#  tion)
#
#  BaseCNNB2_3_Conv1x1-A (Conv2D)  (None, 3, 3, 256)   262400      ['BaseCNNB2_2_ReLU-Final[0][0]']
#
#  batch_normalization_14065 (Bat  (None, 3, 3, 256)   1024        ['BaseCNNB2_3_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB2_3_ReLU-A (Activation  (None, 3, 3, 256)   0           ['batch_normalization_14065[0][0]
#  )                                                               ']
#
#  BaseCNNB2_3_Conv3x3-B (Conv2D)  (None, 3, 3, 256)   590080      ['BaseCNNB2_3_ReLU-A[0][0]']
#
#  batch_normalization_14066 (Bat  (None, 3, 3, 256)   1024        ['BaseCNNB2_3_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB2_3_ReLU-B (Activation  (None, 3, 3, 256)   0           ['batch_normalization_14066[0][0]
#  )                                                               ']
#
#  BaseCNNB2_3_Conv1x1-C (Conv2D)  (None, 3, 3, 1024)  263168      ['BaseCNNB2_3_ReLU-B[0][0]']
#
#  batch_normalization_14067 (Bat  (None, 3, 3, 1024)  4096        ['BaseCNNB2_3_Conv1x1-C[0][0]']
#  chNormalization)
#
#  add_4194 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_14067[0][0]
#                                                                  ',
#                                                                   'BaseCNNB2_2_ReLU-Final[0][0]']
#
#  BaseCNNB2_3_ReLU-Final (Activa  (None, 3, 3, 1024)  0           ['add_4194[0][0]']
#  tion)
#
#  conv2d_14289 (Conv2D)          (None, 3, 3, 2048)   2099200     ['BaseCNNB2_3_ReLU-Final[0][0]']
#
#  batch_normalization_14068 (Bat  (None, 3, 3, 2048)  8192        ['conv2d_14289[0][0]']
#  chNormalization)
#
#  BaseCNNB3_1_Conv1x1-A_firstblo  (None, 2, 2, 512)   1049088     ['batch_normalization_14068[0][0]
#  ck (Conv2D)                                                     ']
#
#  batch_normalization_14070 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_1_Conv1x1-A_firstbloc
#  chNormalization)                                                k[0][0]']
#
#  BaseCNNB3_1_ReLU-A (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14070[0][0]
#  )                                                               ']
#
#  BaseCNNB3_1_Conv3x3-B (Conv2D)  (None, 2, 2, 512)   2359808     ['BaseCNNB3_1_ReLU-A[0][0]']
#
#  batch_normalization_14071 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_1_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB3_1_ReLU-B (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14071[0][0]
#  )                                                               ']
#
#  BaseCNNB3_1_Conv1x1-C (Conv2D)  (None, 2, 2, 2048)  1050624     ['BaseCNNB3_1_ReLU-B[0][0]']
#
#  conv2d_14290 (Conv2D)          (None, 2, 2, 2048)   2099200     ['BaseCNNB2_3_ReLU-Final[0][0]']
#
#  batch_normalization_14072 (Bat  (None, 2, 2, 2048)  8192        ['BaseCNNB3_1_Conv1x1-C[0][0]']
#  chNormalization)
#
#  batch_normalization_14069 (Bat  (None, 2, 2, 2048)  8192        ['conv2d_14290[0][0]']
#  chNormalization)
#
#  add_4195 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_14072[0][0]
#                                                                  ',
#                                                                   'batch_normalization_14069[0][0]
#                                                                  ']
#
#  BaseCNNB3_1_ReLU-Final (Activa  (None, 2, 2, 2048)  0           ['add_4195[0][0]']
#  tion)
#
#  BaseCNNB3_2_Conv1x1-A (Conv2D)  (None, 2, 2, 512)   1049088     ['BaseCNNB3_1_ReLU-Final[0][0]']
#
#  batch_normalization_14073 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_2_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB3_2_ReLU-A (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14073[0][0]
#  )                                                               ']
#
#  BaseCNNB3_2_Conv3x3-B (Conv2D)  (None, 2, 2, 512)   2359808     ['BaseCNNB3_2_ReLU-A[0][0]']
#
#  batch_normalization_14074 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_2_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB3_2_ReLU-B (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14074[0][0]
#  )                                                               ']
#
#  BaseCNNB3_2_Conv1x1-C (Conv2D)  (None, 2, 2, 2048)  1050624     ['BaseCNNB3_2_ReLU-B[0][0]']
#
#  batch_normalization_14075 (Bat  (None, 2, 2, 2048)  8192        ['BaseCNNB3_2_Conv1x1-C[0][0]']
#  chNormalization)
#
#  add_4196 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_14075[0][0]
#                                                                  ',
#                                                                   'BaseCNNB3_1_ReLU-Final[0][0]']
#
#  BaseCNNB3_2_ReLU-Final (Activa  (None, 2, 2, 2048)  0           ['add_4196[0][0]']
#  tion)
#
#  BaseCNNB3_3_Conv1x1-A (Conv2D)  (None, 2, 2, 512)   1049088     ['BaseCNNB3_2_ReLU-Final[0][0]']
#
#  batch_normalization_14076 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_3_Conv1x1-A[0][0]']
#  chNormalization)
#
#  BaseCNNB3_3_ReLU-A (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14076[0][0]
#  )                                                               ']
#
#  BaseCNNB3_3_Conv3x3-B (Conv2D)  (None, 2, 2, 512)   2359808     ['BaseCNNB3_3_ReLU-A[0][0]']
#
#  batch_normalization_14077 (Bat  (None, 2, 2, 512)   2048        ['BaseCNNB3_3_Conv3x3-B[0][0]']
#  chNormalization)
#
#  BaseCNNB3_3_ReLU-B (Activation  (None, 2, 2, 512)   0           ['batch_normalization_14077[0][0]
#  )                                                               ']
#
#  BaseCNNB3_3_Conv1x1-C (Conv2D)  (None, 2, 2, 2048)  1050624     ['BaseCNNB3_3_ReLU-B[0][0]']
#
#  batch_normalization_14078 (Bat  (None, 2, 2, 2048)  8192        ['BaseCNNB3_3_Conv1x1-C[0][0]']
#  chNormalization)
#
#  add_4197 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_14078[0][0]
#                                                                  ',
#                                                                   'BaseCNNB3_2_ReLU-Final[0][0]']
#
#  BaseCNNB3_3_ReLU-Final (Activa  (None, 2, 2, 2048)  0           ['add_4197[0][0]']
#  tion)
#
#  lambda_175 (Lambda)            (None, 2048)         0           ['BaseCNNB3_3_ReLU-Final[0][0]']
#
#  dense_401 (Dense)              (None, 1024)         2098176     ['lambda_175[0][0]']
#
#  dropout_45 (Dropout)           (None, 1024)         0           ['dense_401[0][0]']
#
#  dense_402 (Dense)              (None, 1)            1025        ['dropout_45[0][0]']
#
# ==================================================================================================
# Total params: 29,564,289
# Trainable params: 29,504,385
# Non-trainable params: 59,904
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, AveragePooling2D
from keras.models import Model

input_shape = (41, 41, 1)
reg = 0.00001

def print_layer_dimensions(model):
    for layer in model.layers:
        print(f"Layer: {layer.name}, Input Shape: {layer.input_shape}")
        print(f"Layer: {layer.name}, Output Shape: {layer.output_shape}")
    print("#########################################################")

def create_earlymax_model_b0(models,inputs):
    
    def inner_block(input, filters,outer_nr,inner_nr, strides=(1, 1), firstblock = False,):
        shortcut = input

        bname = model_name + outer_nr + inner_nr

        if input.shape[-1] != filters:
            input = Conv2D(filters, (1, 1), strides=strides, padding='same')(input)
            input = BatchNormalization()(input)    

        if firstblock == True: 
            xaname = bname + "_Conv1x1-A_firstblock"
            xa = Conv2D(filters // 4, (1, 1), strides=(2,2), padding='same',name=xaname)(input)
            shortcut = Conv2D(filters, (1, 1), strides=(2,2), padding='same')(shortcut)
            shortcut = BatchNormalization()(shortcut)
        else: 
            xaname = bname + "_Conv1x1-A"
            xa = Conv2D(filters // 4, (1, 1), strides=strides, padding='same',name=xaname)(input)

        xbname = bname + "_BatchNorm-A" 
        xb = BatchNormalization()(xa)
        xcname = bname + "_ReLU-A" 
        xc = Activation('relu',name=xcname)(xb)
        xdname = bname + "_Conv3x3-B" 
        xd = Conv2D(filters // 4, (3, 3), strides=strides, padding='same',name = xdname)(xc)
        xename = bname + "_BatchNorm-B"
        xe = BatchNormalization()(xd)
        xfname = bname + "_ReLU-B"
        xf = Activation('relu',name=xfname)(xe)
        xgname = bname +"_Conv1x1-C"
        xg = Conv2D(filters, (1, 1), strides=strides, padding='same',name=xgname)(xf)
        xhname = bname + "_BatchNorm-C"
        xh = BatchNormalization()(xg)

        xiname = bname + "_ResidualConnection"
        xi = Add()([xh, shortcut])
        xjname = bname + "_ReLU-Final"
        xj = Activation('relu',name=xjname)(xi)
        return xj
    
    def outer_block(input,num_filters,block_nr):
        x1 = inner_block(input,num_filters,block_nr,'_1',firstblock=True)
        x2 = inner_block(x1,num_filters,block_nr,'_2')
        x3 = inner_block(x2,num_filters,block_nr,'_3')
        return x3
    
    ## nn1_block_idx = 35 for Block 0_3 Final Activation Output
    nn1_block_idx = 35


    for model in models:
        print(model.layers[nn1_block_idx].output.shape)

    layer_outputs =     [model.layers[nn1_block_idx].output for model in models]

    fusionlayer = Concatenate(axis=-1)(layer_outputs)
    print("Fusionlayer after Concatenation:" ,fusionlayer.shape)

    #fusionlayer = Reshape((11, 11, 1024, 4))(fusionlayer)
    #fusionlayer = Reshape((*fusionlayer.shape[1:],4))(fusionlayer)
    fusionlayer = Reshape((fusionlayer.shape[1], fusionlayer.shape[2], fusionlayer.shape[3] // 4, 4))(fusionlayer)

    print("Fusionlayer after Reshape:" ,fusionlayer.shape)

    max_pooling_function = Lambda(lambda x: K.max(x, axis=-1, keepdims=False))
    fusionlayer = max_pooling_function(fusionlayer)   
    print("Fusionlayer after MaxPooling:",fusionlayer.shape)

    model_name = "CNN2"
    b1 = outer_block(fusionlayer,512,'B1')
    b2 = outer_block(b1,1024,'B2')
    b3 = outer_block(b2,2048,'B3')

    avgpool = Lambda(lambda x: K.mean(x, axis=(1, 2), keepdims=False))(b3)
    dense1024 = Dense(units=1024, activation='softmax')(avgpool)

    x = Dropout(0.5)(dense1024)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_multi = Model(inputs,outputs)
    print_layer_dimensions(model_multi)

    return model_multi

input_1 = Input(shape=input_shape)
cnn_model_1 = create_custom_resnet(input_1,'Model1')
input_2 = Input(shape=input_shape)
cnn_model_2 = create_custom_resnet(input_2,'Model2')
input_3 = Input(shape=input_shape)
cnn_model_3 = create_custom_resnet(input_3,'Model3')
input_4 = Input(shape=input_shape)
cnn_model_4 = create_custom_resnet(input_4,'Model4')    

print("################################################################")

model_multi = create_earlymax_model_b0([cnn_model_1, cnn_model_2, cnn_model_3, cnn_model_4],[input_1, input_2, input_3, input_4])
model_multi.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_multi.summary()
# Out:
# Layer: input_139, Input Shape: [(None, 41, 41, 1)]
# Layer: input_139, Output Shape: [(None, 41, 41, 1)]
# Layer: Model1_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model1_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1195, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1195, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6577, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6577, Output Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6579, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6579, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6580, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6580, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1196, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1196, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6581, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6581, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6578, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6578, Output Shape: (None, 11, 11, 1024)
# Layer: add_1794, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1794, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6582, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6582, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6583, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6583, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6584, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6584, Output Shape: (None, 11, 11, 1024)
# Layer: add_1795, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1795, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6585, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6585, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6586, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6586, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6587, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6587, Output Shape: (None, 11, 11, 1024)
# Layer: add_1796, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1796, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1197, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1197, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6588, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6588, Output Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6590, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6590, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6591, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6591, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1198, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1198, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6592, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6592, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6589, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6589, Output Shape: (None, 6, 6, 512)
# Layer: add_1797, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1797, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6593, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6593, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6594, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6594, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6595, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6595, Output Shape: (None, 6, 6, 512)
# Layer: add_1798, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1798, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6596, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6596, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6597, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6597, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6598, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6598, Output Shape: (None, 6, 6, 512)
# Layer: add_1799, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1799, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1199, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1199, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6599, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6599, Output Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6601, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6601, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6602, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6602, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1200, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1200, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6603, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6603, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6600, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6600, Output Shape: (None, 3, 3, 1024)
# Layer: add_1800, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1800, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6604, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6604, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6605, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6605, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6606, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6606, Output Shape: (None, 3, 3, 1024)
# Layer: add_1801, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1801, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6607, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6607, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6608, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6608, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6609, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6609, Output Shape: (None, 3, 3, 1024)
# Layer: add_1802, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1802, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1201, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1201, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6610, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6610, Output Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6612, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6612, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6613, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6613, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_1202, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1202, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6614, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6614, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6611, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6611, Output Shape: (None, 2, 2, 2048)
# Layer: add_1803, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1803, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6615, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6615, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6616, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6616, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6617, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6617, Output Shape: (None, 2, 2, 2048)
# Layer: add_1804, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1804, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6618, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6618, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6619, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6619, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6620, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6620, Output Shape: (None, 2, 2, 2048)
# Layer: add_1805, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1805, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_177, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_177, Output Shape: (None, 2048)
# Layer: dense_180, Input Shape: (None, 2048)
# Layer: dense_180, Output Shape: (None, 1024)
# #########################################################
# Layer: input_140, Input Shape: [(None, 41, 41, 1)]
# Layer: input_140, Output Shape: [(None, 41, 41, 1)]
# Layer: Model2_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model2_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1203, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1203, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6621, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6621, Output Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6623, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6623, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6624, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6624, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1204, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1204, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6625, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6625, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6622, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6622, Output Shape: (None, 11, 11, 1024)
# Layer: add_1806, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1806, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6626, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6626, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6627, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6627, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6628, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6628, Output Shape: (None, 11, 11, 1024)
# Layer: add_1807, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1807, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6629, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6629, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6630, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6630, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6631, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6631, Output Shape: (None, 11, 11, 1024)
# Layer: add_1808, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1808, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1205, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1205, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6632, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6632, Output Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6634, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6634, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6635, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6635, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1206, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1206, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6636, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6636, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6633, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6633, Output Shape: (None, 6, 6, 512)
# Layer: add_1809, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1809, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6637, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6637, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6638, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6638, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6639, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6639, Output Shape: (None, 6, 6, 512)
# Layer: add_1810, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1810, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6640, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6640, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6641, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6641, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6642, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6642, Output Shape: (None, 6, 6, 512)
# Layer: add_1811, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1811, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1207, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1207, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6643, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6643, Output Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6645, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6645, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6646, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6646, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1208, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1208, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6647, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6647, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6644, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6644, Output Shape: (None, 3, 3, 1024)
# Layer: add_1812, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1812, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6648, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6648, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6649, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6649, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6650, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6650, Output Shape: (None, 3, 3, 1024)
# Layer: add_1813, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1813, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6651, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6651, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6652, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6652, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6653, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6653, Output Shape: (None, 3, 3, 1024)
# Layer: add_1814, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1814, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1209, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1209, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6654, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6654, Output Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6656, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6656, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6657, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6657, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_1210, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1210, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6658, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6658, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6655, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6655, Output Shape: (None, 2, 2, 2048)
# Layer: add_1815, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1815, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6659, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6659, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6660, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6660, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6661, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6661, Output Shape: (None, 2, 2, 2048)
# Layer: add_1816, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1816, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6662, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6662, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6663, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6663, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6664, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6664, Output Shape: (None, 2, 2, 2048)
# Layer: add_1817, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1817, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_178, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_178, Output Shape: (None, 2048)
# Layer: dense_181, Input Shape: (None, 2048)
# Layer: dense_181, Output Shape: (None, 1024)
# #########################################################
# Layer: input_141, Input Shape: [(None, 41, 41, 1)]
# Layer: input_141, Output Shape: [(None, 41, 41, 1)]
# Layer: Model3_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model3_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1211, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1211, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6665, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6665, Output Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6667, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6667, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6668, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6668, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1212, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1212, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6669, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6669, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6666, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6666, Output Shape: (None, 11, 11, 1024)
# Layer: add_1818, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1818, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6670, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6670, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6671, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6671, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6672, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6672, Output Shape: (None, 11, 11, 1024)
# Layer: add_1819, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1819, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6673, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6673, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6674, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6674, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6675, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6675, Output Shape: (None, 11, 11, 1024)
# Layer: add_1820, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1820, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1213, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1213, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6676, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6676, Output Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6678, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6678, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6679, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6679, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1214, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1214, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6680, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6680, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6677, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6677, Output Shape: (None, 6, 6, 512)
# Layer: add_1821, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1821, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6681, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6681, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6682, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6682, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6683, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6683, Output Shape: (None, 6, 6, 512)
# Layer: add_1822, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1822, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6684, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6684, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6685, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6685, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6686, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6686, Output Shape: (None, 6, 6, 512)
# Layer: add_1823, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1823, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1215, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1215, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6687, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6687, Output Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6689, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6689, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6690, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6690, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1216, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1216, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6691, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6691, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6688, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6688, Output Shape: (None, 3, 3, 1024)
# Layer: add_1824, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1824, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6692, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6692, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6693, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6693, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6694, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6694, Output Shape: (None, 3, 3, 1024)
# Layer: add_1825, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1825, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6695, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6695, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6696, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6696, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6697, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6697, Output Shape: (None, 3, 3, 1024)
# Layer: add_1826, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1826, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1217, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1217, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6698, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6698, Output Shape: (None, 3, 3, 2048)
# Layer: Model3B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model3B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6700, Input Shape: (None, 2, 2, 512)
# ...
#  CNN2B2_1_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1845[0][0]']
#  n)
#
#  CNN2B2_2_Conv1x1-A (Conv2D)    (None, 3, 3, 256)    262400      ['CNN2B2_1_ReLU-Final[0][0]']
#
#  batch_normalization_6769 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_2_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B2_2_ReLU-A (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6769[0][0]'
#                                                                  ]
#
#  CNN2B2_2_Conv3x3-B (Conv2D)    (None, 3, 3, 256)    590080      ['CNN2B2_2_ReLU-A[0][0]']
#
#  batch_normalization_6770 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_2_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B2_2_ReLU-B (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6770[0][0]'
#                                                                  ]
#
#  CNN2B2_2_Conv1x1-C (Conv2D)    (None, 3, 3, 1024)   263168      ['CNN2B2_2_ReLU-B[0][0]']
#
#  batch_normalization_6771 (Batc  (None, 3, 3, 1024)  4096        ['CNN2B2_2_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1846 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_6771[0][0]'
#                                                                  , 'CNN2B2_1_ReLU-Final[0][0]']
#
#  CNN2B2_2_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1846[0][0]']
#  n)
#
#  CNN2B2_3_Conv1x1-A (Conv2D)    (None, 3, 3, 256)    262400      ['CNN2B2_2_ReLU-Final[0][0]']
#
#  batch_normalization_6772 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_3_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B2_3_ReLU-A (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6772[0][0]'
#                                                                  ]
#
#  CNN2B2_3_Conv3x3-B (Conv2D)    (None, 3, 3, 256)    590080      ['CNN2B2_3_ReLU-A[0][0]']
#
#  batch_normalization_6773 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_3_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B2_3_ReLU-B (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6773[0][0]'
#                                                                  ]
#
#  CNN2B2_3_Conv1x1-C (Conv2D)    (None, 3, 3, 1024)   263168      ['CNN2B2_3_ReLU-B[0][0]']
#
#  batch_normalization_6774 (Batc  (None, 3, 3, 1024)  4096        ['CNN2B2_3_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1847 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_6774[0][0]'
#                                                                  , 'CNN2B2_2_ReLU-Final[0][0]']
#
#  CNN2B2_3_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1847[0][0]']
#  n)
#
#  conv2d_1231 (Conv2D)           (None, 3, 3, 2048)   2099200     ['CNN2B2_3_ReLU-Final[0][0]']
#
#  batch_normalization_6775 (Batc  (None, 3, 3, 2048)  8192        ['conv2d_1231[0][0]']
#  hNormalization)
#
#  CNN2B3_1_Conv1x1-A_firstblock   (None, 2, 2, 512)   1049088     ['batch_normalization_6775[0][0]'
#  (Conv2D)                                                        ]
#
#  batch_normalization_6777 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_1_Conv1x1-A_firstblock[0
#  hNormalization)                                                 ][0]']
#
#  CNN2B3_1_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6777[0][0]'
#                                                                  ]
#
#  CNN2B3_1_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_1_ReLU-A[0][0]']
#
#  batch_normalization_6778 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_1_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_1_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6778[0][0]'
#                                                                  ]
#
#  CNN2B3_1_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_1_ReLU-B[0][0]']
#
#  conv2d_1232 (Conv2D)           (None, 2, 2, 2048)   2099200     ['CNN2B2_3_ReLU-Final[0][0]']
#
#  batch_normalization_6779 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_1_Conv1x1-C[0][0]']
#  hNormalization)
#
#  batch_normalization_6776 (Batc  (None, 2, 2, 2048)  8192        ['conv2d_1232[0][0]']
#  hNormalization)
#
#  add_1848 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6779[0][0]'
#                                                                  , 'batch_normalization_6776[0][0]
#                                                                  ']
#
#  CNN2B3_1_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1848[0][0]']
#  n)
#
#  CNN2B3_2_Conv1x1-A (Conv2D)    (None, 2, 2, 512)    1049088     ['CNN2B3_1_ReLU-Final[0][0]']
#
#  batch_normalization_6780 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_2_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B3_2_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6780[0][0]'
#                                                                  ]
#
#  CNN2B3_2_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_2_ReLU-A[0][0]']
#
#  batch_normalization_6781 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_2_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_2_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6781[0][0]'
#                                                                  ]
#
#  CNN2B3_2_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_2_ReLU-B[0][0]']
#
#  batch_normalization_6782 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_2_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1849 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6782[0][0]'
#                                                                  , 'CNN2B3_1_ReLU-Final[0][0]']
#
#  CNN2B3_2_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1849[0][0]']
#  n)
#
#  CNN2B3_3_Conv1x1-A (Conv2D)    (None, 2, 2, 512)    1049088     ['CNN2B3_2_ReLU-Final[0][0]']
#
#  batch_normalization_6783 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_3_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B3_3_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6783[0][0]'
#                                                                  ]
#
#  CNN2B3_3_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_3_ReLU-A[0][0]']
#
#  batch_normalization_6784 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_3_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_3_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6784[0][0]'
#                                                                  ]
#
#  CNN2B3_3_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_3_ReLU-B[0][0]']
#
#  batch_normalization_6785 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_3_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1850 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6785[0][0]'
#                                                                  , 'CNN2B3_2_ReLU-Final[0][0]']
#
#  CNN2B3_3_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1850[0][0]']
#  n)
#
#  lambda_182 (Lambda)            (None, 2048)         0           ['CNN2B3_3_ReLU-Final[0][0]']
#
#  dense_184 (Dense)              (None, 1024)         2098176     ['lambda_182[0][0]']
#
#  dropout_22 (Dropout)           (None, 1024)         0           ['dense_184[0][0]']
#
#  dense_185 (Dense)              (None, 1)            1025        ['dropout_22[0][0]']
#
# ==================================================================================================
# Total params: 40,093,953
# Trainable params: 39,994,113
# Non-trainable params: 99,840
# __________________________________________________________________________________________________

# %%
def create_earlymax_model_b1(models,inputs):
    
    def inner_block(input, filters,outer_nr,inner_nr, strides=(1, 1), firstblock = False,):
        shortcut = input

        bname = model_name + outer_nr + inner_nr

        if input.shape[-1] != filters:
            inputconvname = bname + "_InpuConv"
            input = Conv2D(filters, (1, 1), strides=strides, padding='same')(input)
            input = BatchNormalization()(input)    

        if firstblock == True: 
            xaname = bname + "_Conv1x1-A_firstblock"
            xa = Conv2D(filters // 4, (1, 1), strides=(2,2), padding='same',name=xaname)(input)
            inputconvname = bname + "_InpuConv"
            shortcut = Conv2D(filters, (1, 1), strides=(2,2), padding='same')(shortcut)
            shortcut = BatchNormalization()(shortcut)
        else: 
            xaname = bname + "_Conv1x1-A"
            xa = Conv2D(filters // 4, (1, 1), strides=strides, padding='same',name=xaname)(input)

        xbname = bname + "_BatchNorm-A" 
        xb = BatchNormalization()(xa)
        xcname = bname + "_ReLU-A" 
        xc = Activation('relu',name=xcname)(xb)
        xdname = bname + "_Conv3x3-B" 
        xd = Conv2D(filters // 4, (3, 3), strides=strides, padding='same',name = xdname)(xc)
        xename = bname + "_BatchNorm-B"
        xe = BatchNormalization()(xd)
        xfname = bname + "_ReLU-B"
        xf = Activation('relu',name=xfname)(xe)
        xgname = bname +"_Conv1x1-C"
        xg = Conv2D(filters, (1, 1), strides=strides, padding='same',name=xgname)(xf)
        xhname = bname + "_BatchNorm-C"
        xh = BatchNormalization()(xg)

        xiname = bname + "_ResidualConnection"
        xi = Add()([xh, shortcut])
        xjname = bname + "_ReLU-Final"
        xj = Activation('relu',name=xjname)(xi)
        return xj
    
    def outer_block(input,num_filters,block_nr):
        x1 = inner_block(input,num_filters,block_nr,'_1',firstblock=True)
        x2 = inner_block(x1,num_filters,block_nr,'_2')
        x3 = inner_block(x2,num_filters,block_nr,'_3')
        return x3
    
    ## nn1_block_idx = 34 for Block 0_3 Final Activation Output
    nn1_block_idx = 69 #Try searching by name


    for model in models:
        print(model.layers[nn1_block_idx].output.shape)

    layer_outputs =     [model.layers[nn1_block_idx].output for model in models]

    fusionlayer = Concatenate(axis=-1)(layer_outputs)
    print("Fusionlayer after Concatenation:" ,fusionlayer.shape)

    fusionlayer = Reshape((fusionlayer.shape[1], fusionlayer.shape[2], fusionlayer.shape[3] // 4, 4))(fusionlayer)
    print("Fusionlayer after Reshape:" ,fusionlayer.shape)

    max_pooling_function = Lambda(lambda x: K.max(x, axis=-1, keepdims=False))
    fusionlayer = max_pooling_function(fusionlayer)   
    print("Fusionlayer after MaxPooling:",fusionlayer.shape)

    model_name = "CNN2"
    #b1 = outer_block(fusionlayer,512,'B1')
    b2 = outer_block(fusionlayer,1024,'B2')
    b3 = outer_block(b2,2048,'B3')

    avgpool = Lambda(lambda x: K.mean(x, axis=(1, 2), keepdims=False))(b3)
    dense1024 = Dense(units=1024, activation='softmax')(avgpool)

    x = Dropout(0.5)(dense1024)
    outputs = Dense(units=1, activation='sigmoid')(x)
    model_multi = Model(inputs,outputs)
    print_layer_dimensions(model_multi)

    return model_multi

input_1 = Input(shape=input_shape)
cnn_model_1 = create_custom_resnet(input_1,'Model1')
input_2 = Input(shape=input_shape)
cnn_model_2 = create_custom_resnet(input_2,'Model2')
input_3 = Input(shape=input_shape)
cnn_model_3 = create_custom_resnet(input_3,'Model3')
input_4 = Input(shape=input_shape)
cnn_model_4 = create_custom_resnet(input_4,'Model4')    

print("################################################################")

model_multi = create_earlymax_model_b1([cnn_model_1, cnn_model_2, cnn_model_3, cnn_model_4],[input_1, input_2, input_3, input_4])
model_multi.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_multi.summary()
# Out:
# Layer: input_135, Input Shape: [(None, 41, 41, 1)]
# Layer: input_135, Output Shape: [(None, 41, 41, 1)]
# Layer: Model1_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model1_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1159, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1159, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6379, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6379, Output Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model1B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6381, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6381, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6382, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6382, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1160, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1160, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6383, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6383, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6380, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6380, Output Shape: (None, 11, 11, 1024)
# Layer: add_1740, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1740, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6384, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6384, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6385, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6385, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6386, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6386, Output Shape: (None, 11, 11, 1024)
# Layer: add_1741, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1741, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6387, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6387, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6388, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6388, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model1B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6389, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6389, Output Shape: (None, 11, 11, 1024)
# Layer: add_1742, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1742, Output Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model1B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1161, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1161, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6390, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6390, Output Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model1B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6392, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6392, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6393, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6393, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1162, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1162, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6394, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6394, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6391, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6391, Output Shape: (None, 6, 6, 512)
# Layer: add_1743, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1743, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6395, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6395, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6396, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6396, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6397, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6397, Output Shape: (None, 6, 6, 512)
# Layer: add_1744, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1744, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6398, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6398, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6399, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6399, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model1B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6400, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6400, Output Shape: (None, 6, 6, 512)
# Layer: add_1745, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1745, Output Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model1B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1163, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1163, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6401, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6401, Output Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model1B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6403, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6403, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6404, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6404, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1164, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1164, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6405, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6405, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6402, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6402, Output Shape: (None, 3, 3, 1024)
# Layer: add_1746, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1746, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6406, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6406, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6407, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6407, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6408, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6408, Output Shape: (None, 3, 3, 1024)
# Layer: add_1747, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1747, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6409, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6409, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6410, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6410, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model1B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6411, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6411, Output Shape: (None, 3, 3, 1024)
# Layer: add_1748, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1748, Output Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model1B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1165, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1165, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6412, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6412, Output Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model1B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6414, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6414, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6415, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6415, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_1166, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1166, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6416, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6416, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6413, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6413, Output Shape: (None, 2, 2, 2048)
# Layer: add_1749, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1749, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6417, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6417, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6418, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6418, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6419, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6419, Output Shape: (None, 2, 2, 2048)
# Layer: add_1750, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1750, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6420, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6420, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6421, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6421, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model1B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6422, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6422, Output Shape: (None, 2, 2, 2048)
# Layer: add_1751, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1751, Output Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model1B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_171, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_171, Output Shape: (None, 2048)
# Layer: dense_174, Input Shape: (None, 2048)
# Layer: dense_174, Output Shape: (None, 1024)
# #########################################################
# Layer: input_136, Input Shape: [(None, 41, 41, 1)]
# Layer: input_136, Output Shape: [(None, 41, 41, 1)]
# Layer: Model2_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model2_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1167, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1167, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6423, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6423, Output Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model2B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6425, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6425, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6426, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6426, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1168, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1168, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6427, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6427, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6424, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6424, Output Shape: (None, 11, 11, 1024)
# Layer: add_1752, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1752, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6428, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6428, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6429, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6429, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6430, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6430, Output Shape: (None, 11, 11, 1024)
# Layer: add_1753, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1753, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6431, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6431, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6432, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6432, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model2B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6433, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6433, Output Shape: (None, 11, 11, 1024)
# Layer: add_1754, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1754, Output Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model2B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1169, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1169, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6434, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6434, Output Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model2B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6436, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6436, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6437, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6437, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1170, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1170, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6438, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6438, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6435, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6435, Output Shape: (None, 6, 6, 512)
# Layer: add_1755, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1755, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6439, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6439, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6440, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6440, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6441, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6441, Output Shape: (None, 6, 6, 512)
# Layer: add_1756, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1756, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6442, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6442, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6443, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6443, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model2B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6444, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6444, Output Shape: (None, 6, 6, 512)
# Layer: add_1757, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1757, Output Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model2B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1171, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1171, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6445, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6445, Output Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model2B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6447, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6447, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6448, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6448, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1172, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1172, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6449, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6449, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6446, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6446, Output Shape: (None, 3, 3, 1024)
# Layer: add_1758, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1758, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6450, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6450, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6451, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6451, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6452, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6452, Output Shape: (None, 3, 3, 1024)
# Layer: add_1759, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1759, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6453, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6453, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6454, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6454, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model2B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6455, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6455, Output Shape: (None, 3, 3, 1024)
# Layer: add_1760, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1760, Output Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model2B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1173, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1173, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6456, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6456, Output Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model2B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6458, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6458, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6459, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6459, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_1_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: conv2d_1174, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1174, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6460, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6460, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6457, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6457, Output Shape: (None, 2, 2, 2048)
# Layer: add_1761, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1761, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_1_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6461, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6461, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6462, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6462, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_2_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6463, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6463, Output Shape: (None, 2, 2, 2048)
# Layer: add_1762, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1762, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_2_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_Conv1x1-A, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6464, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6464, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-A, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv3x3-B, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6465, Input Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6465, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_ReLU-B, Output Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Input Shape: (None, 2, 2, 512)
# Layer: Model2B3_3_Conv1x1-C, Output Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6466, Input Shape: (None, 2, 2, 2048)
# Layer: batch_normalization_6466, Output Shape: (None, 2, 2, 2048)
# Layer: add_1763, Input Shape: [(None, 2, 2, 2048), (None, 2, 2, 2048)]
# Layer: add_1763, Output Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Input Shape: (None, 2, 2, 2048)
# Layer: Model2B3_3_ReLU-Final, Output Shape: (None, 2, 2, 2048)
# Layer: lambda_172, Input Shape: (None, 2, 2, 2048)
# Layer: lambda_172, Output Shape: (None, 2048)
# Layer: dense_175, Input Shape: (None, 2048)
# Layer: dense_175, Output Shape: (None, 1024)
# #########################################################
# Layer: input_137, Input Shape: [(None, 41, 41, 1)]
# Layer: input_137, Output Shape: [(None, 41, 41, 1)]
# Layer: Model3_InputConvolution, Input Shape: (None, 41, 41, 1)
# Layer: Model3_InputConvolution, Output Shape: (None, 21, 21, 64)
# Layer: conv2d_1175, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1175, Output Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6467, Input Shape: (None, 21, 21, 1024)
# Layer: batch_normalization_6467, Output Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Input Shape: (None, 21, 21, 1024)
# Layer: Model3B0_1_Conv1x1-A_firstblock, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6469, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6469, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6470, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6470, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_1_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1176, Input Shape: (None, 21, 21, 64)
# Layer: conv2d_1176, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6471, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6471, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6468, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6468, Output Shape: (None, 11, 11, 1024)
# Layer: add_1764, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1764, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_1_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6472, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6472, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6473, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6473, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_2_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6474, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6474, Output Shape: (None, 11, 11, 1024)
# Layer: add_1765, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1765, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_2_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_Conv1x1-A, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6475, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6475, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-A, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv3x3-B, Output Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6476, Input Shape: (None, 11, 11, 256)
# Layer: batch_normalization_6476, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_ReLU-B, Output Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Input Shape: (None, 11, 11, 256)
# Layer: Model3B0_3_Conv1x1-C, Output Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6477, Input Shape: (None, 11, 11, 1024)
# Layer: batch_normalization_6477, Output Shape: (None, 11, 11, 1024)
# Layer: add_1766, Input Shape: [(None, 11, 11, 1024), (None, 11, 11, 1024)]
# Layer: add_1766, Output Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Input Shape: (None, 11, 11, 1024)
# Layer: Model3B0_3_ReLU-Final, Output Shape: (None, 11, 11, 1024)
# Layer: conv2d_1177, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1177, Output Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6478, Input Shape: (None, 11, 11, 512)
# Layer: batch_normalization_6478, Output Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Input Shape: (None, 11, 11, 512)
# Layer: Model3B1_1_Conv1x1-A_firstblock, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6480, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6480, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6481, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6481, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_1_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1178, Input Shape: (None, 11, 11, 1024)
# Layer: conv2d_1178, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6482, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6482, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6479, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6479, Output Shape: (None, 6, 6, 512)
# Layer: add_1767, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1767, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_1_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6483, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6483, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6484, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6484, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_2_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6485, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6485, Output Shape: (None, 6, 6, 512)
# Layer: add_1768, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1768, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_2_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_Conv1x1-A, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6486, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6486, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-A, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv3x3-B, Output Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6487, Input Shape: (None, 6, 6, 128)
# Layer: batch_normalization_6487, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_ReLU-B, Output Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Input Shape: (None, 6, 6, 128)
# Layer: Model3B1_3_Conv1x1-C, Output Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6488, Input Shape: (None, 6, 6, 512)
# Layer: batch_normalization_6488, Output Shape: (None, 6, 6, 512)
# Layer: add_1769, Input Shape: [(None, 6, 6, 512), (None, 6, 6, 512)]
# Layer: add_1769, Output Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Input Shape: (None, 6, 6, 512)
# Layer: Model3B1_3_ReLU-Final, Output Shape: (None, 6, 6, 512)
# Layer: conv2d_1179, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1179, Output Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6489, Input Shape: (None, 6, 6, 1024)
# Layer: batch_normalization_6489, Output Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Input Shape: (None, 6, 6, 1024)
# Layer: Model3B2_1_Conv1x1-A_firstblock, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6491, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6491, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6492, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6492, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_1_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1180, Input Shape: (None, 6, 6, 512)
# Layer: conv2d_1180, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6493, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6493, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6490, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6490, Output Shape: (None, 3, 3, 1024)
# Layer: add_1770, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1770, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_1_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6494, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6494, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6495, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6495, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_2_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6496, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6496, Output Shape: (None, 3, 3, 1024)
# Layer: add_1771, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1771, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_2_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_Conv1x1-A, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6497, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6497, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-A, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv3x3-B, Output Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6498, Input Shape: (None, 3, 3, 256)
# Layer: batch_normalization_6498, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_ReLU-B, Output Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Input Shape: (None, 3, 3, 256)
# Layer: Model3B2_3_Conv1x1-C, Output Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6499, Input Shape: (None, 3, 3, 1024)
# Layer: batch_normalization_6499, Output Shape: (None, 3, 3, 1024)
# Layer: add_1772, Input Shape: [(None, 3, 3, 1024), (None, 3, 3, 1024)]
# Layer: add_1772, Output Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Input Shape: (None, 3, 3, 1024)
# Layer: Model3B2_3_ReLU-Final, Output Shape: (None, 3, 3, 1024)
# Layer: conv2d_1181, Input Shape: (None, 3, 3, 1024)
# Layer: conv2d_1181, Output Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6500, Input Shape: (None, 3, 3, 2048)
# Layer: batch_normalization_6500, Output Shape: (None, 3, 3, 2048)
# Layer: Model3B3_1_Conv1x1-A_firstblock, Input Shape: (None, 3, 3, 2048)
# Layer: Model3B3_1_Conv1x1-A_firstblock, Output Shape: (None, 2, 2, 512)
# Layer: batch_normalization_6502, Input Shape: (None, 2, 2, 512)
# ...
#  CNN2B2_1_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1788[0][0]']
#  n)
#
#  CNN2B2_2_Conv1x1-A (Conv2D)    (None, 3, 3, 256)    262400      ['CNN2B2_1_ReLU-Final[0][0]']
#
#  batch_normalization_6560 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_2_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B2_2_ReLU-A (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6560[0][0]'
#                                                                  ]
#
#  CNN2B2_2_Conv3x3-B (Conv2D)    (None, 3, 3, 256)    590080      ['CNN2B2_2_ReLU-A[0][0]']
#
#  batch_normalization_6561 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_2_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B2_2_ReLU-B (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6561[0][0]'
#                                                                  ]
#
#  CNN2B2_2_Conv1x1-C (Conv2D)    (None, 3, 3, 1024)   263168      ['CNN2B2_2_ReLU-B[0][0]']
#
#  batch_normalization_6562 (Batc  (None, 3, 3, 1024)  4096        ['CNN2B2_2_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1789 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_6562[0][0]'
#                                                                  , 'CNN2B2_1_ReLU-Final[0][0]']
#
#  CNN2B2_2_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1789[0][0]']
#  n)
#
#  CNN2B2_3_Conv1x1-A (Conv2D)    (None, 3, 3, 256)    262400      ['CNN2B2_2_ReLU-Final[0][0]']
#
#  batch_normalization_6563 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_3_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B2_3_ReLU-A (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6563[0][0]'
#                                                                  ]
#
#  CNN2B2_3_Conv3x3-B (Conv2D)    (None, 3, 3, 256)    590080      ['CNN2B2_3_ReLU-A[0][0]']
#
#  batch_normalization_6564 (Batc  (None, 3, 3, 256)   1024        ['CNN2B2_3_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B2_3_ReLU-B (Activation)   (None, 3, 3, 256)    0           ['batch_normalization_6564[0][0]'
#                                                                  ]
#
#  CNN2B2_3_Conv1x1-C (Conv2D)    (None, 3, 3, 1024)   263168      ['CNN2B2_3_ReLU-B[0][0]']
#
#  batch_normalization_6565 (Batc  (None, 3, 3, 1024)  4096        ['CNN2B2_3_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1790 (Add)                 (None, 3, 3, 1024)   0           ['batch_normalization_6565[0][0]'
#                                                                  , 'CNN2B2_2_ReLU-Final[0][0]']
#
#  CNN2B2_3_ReLU-Final (Activatio  (None, 3, 3, 1024)  0           ['add_1790[0][0]']
#  n)
#
#  conv2d_1193 (Conv2D)           (None, 3, 3, 2048)   2099200     ['CNN2B2_3_ReLU-Final[0][0]']
#
#  batch_normalization_6566 (Batc  (None, 3, 3, 2048)  8192        ['conv2d_1193[0][0]']
#  hNormalization)
#
#  CNN2B3_1_Conv1x1-A_firstblock   (None, 2, 2, 512)   1049088     ['batch_normalization_6566[0][0]'
#  (Conv2D)                                                        ]
#
#  batch_normalization_6568 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_1_Conv1x1-A_firstblock[0
#  hNormalization)                                                 ][0]']
#
#  CNN2B3_1_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6568[0][0]'
#                                                                  ]
#
#  CNN2B3_1_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_1_ReLU-A[0][0]']
#
#  batch_normalization_6569 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_1_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_1_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6569[0][0]'
#                                                                  ]
#
#  CNN2B3_1_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_1_ReLU-B[0][0]']
#
#  conv2d_1194 (Conv2D)           (None, 2, 2, 2048)   2099200     ['CNN2B2_3_ReLU-Final[0][0]']
#
#  batch_normalization_6570 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_1_Conv1x1-C[0][0]']
#  hNormalization)
#
#  batch_normalization_6567 (Batc  (None, 2, 2, 2048)  8192        ['conv2d_1194[0][0]']
#  hNormalization)
#
#  add_1791 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6570[0][0]'
#                                                                  , 'batch_normalization_6567[0][0]
#                                                                  ']
#
#  CNN2B3_1_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1791[0][0]']
#  n)
#
#  CNN2B3_2_Conv1x1-A (Conv2D)    (None, 2, 2, 512)    1049088     ['CNN2B3_1_ReLU-Final[0][0]']
#
#  batch_normalization_6571 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_2_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B3_2_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6571[0][0]'
#                                                                  ]
#
#  CNN2B3_2_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_2_ReLU-A[0][0]']
#
#  batch_normalization_6572 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_2_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_2_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6572[0][0]'
#                                                                  ]
#
#  CNN2B3_2_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_2_ReLU-B[0][0]']
#
#  batch_normalization_6573 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_2_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1792 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6573[0][0]'
#                                                                  , 'CNN2B3_1_ReLU-Final[0][0]']
#
#  CNN2B3_2_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1792[0][0]']
#  n)
#
#  CNN2B3_3_Conv1x1-A (Conv2D)    (None, 2, 2, 512)    1049088     ['CNN2B3_2_ReLU-Final[0][0]']
#
#  batch_normalization_6574 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_3_Conv1x1-A[0][0]']
#  hNormalization)
#
#  CNN2B3_3_ReLU-A (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6574[0][0]'
#                                                                  ]
#
#  CNN2B3_3_Conv3x3-B (Conv2D)    (None, 2, 2, 512)    2359808     ['CNN2B3_3_ReLU-A[0][0]']
#
#  batch_normalization_6575 (Batc  (None, 2, 2, 512)   2048        ['CNN2B3_3_Conv3x3-B[0][0]']
#  hNormalization)
#
#  CNN2B3_3_ReLU-B (Activation)   (None, 2, 2, 512)    0           ['batch_normalization_6575[0][0]'
#                                                                  ]
#
#  CNN2B3_3_Conv1x1-C (Conv2D)    (None, 2, 2, 2048)   1050624     ['CNN2B3_3_ReLU-B[0][0]']
#
#  batch_normalization_6576 (Batc  (None, 2, 2, 2048)  8192        ['CNN2B3_3_Conv1x1-C[0][0]']
#  hNormalization)
#
#  add_1793 (Add)                 (None, 2, 2, 2048)   0           ['batch_normalization_6576[0][0]'
#                                                                  , 'CNN2B3_2_ReLU-Final[0][0]']
#
#  CNN2B3_3_ReLU-Final (Activatio  (None, 2, 2, 2048)  0           ['add_1793[0][0]']
#  n)
#
#  lambda_176 (Lambda)            (None, 2048)         0           ['CNN2B3_3_ReLU-Final[0][0]']
#
#  dense_178 (Dense)              (None, 1024)         2098176     ['lambda_176[0][0]']
#
#  dropout_21 (Dropout)           (None, 1024)         0           ['dense_178[0][0]']
#
#  dense_179 (Dense)              (None, 1)            1025        ['dropout_21[0][0]']
#
# ==================================================================================================
# Total params: 45,796,353
# Trainable params: 45,676,545
# Non-trainable params: 119,808
# __________________________________________________________________________________________________

# %%
num_epochs = 5
batch_size = 64

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(filtered_data, filtered_labels, epochs=num_epochs, batch_size=batch_size,validation_data=(filtered_test_data,filtered_test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> num_epochs = 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> batch_size = 64
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hanneswarnhofer/ECAP_HiWi_WorkingDirectory/Untitled-1.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> model.fit(filtered_data, filtered_labels, epochs=num_epochs, batch_size=batch_size,validation_data=(filtered_test_data,filtered_test_labels))
#
# NameError: name 'model' is not defined

# %%
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks, optimizers, regularizers
from tensorflow.keras.layers import Input, Concatenate, concatenate, Dense,Embedding, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, Flatten, Dropout, ConvLSTM2D, BatchNormalization
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.models import Model, Sequential

input_shape = (41, 41, 1)
pool_size = 2
kernel_size = 4
rate = 0.002
reg = 0.0001
num_epochs = 10
batch_size = 128

# Define the model for the single-view CNNs
def create_cnn_model(input_shape):
    input_layer = Input(shape=input_shape)
    Conv1 = Conv2D(filters=200, kernel_size=kernel_size, padding='same',kernel_regularizer=regularizers.l2(reg), input_shape=input_shape,)(input_layer)
    LeakyRelu1 = LeakyReLU(alpha=0.1)(Conv1)
    MaxPool1 = MaxPooling2D(pool_size=pool_size, padding='same')(LeakyRelu1)

    #print("Before first Dropout")

    Dropout1 = Dropout(rate)(MaxPool1)
    Conv2 = Conv2D(filters=100, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout1)
    LeakyRelu2 = LeakyReLU(alpha=0.1)(Conv2) 
    MaxPool2 = MaxPooling2D(pool_size=pool_size, padding='same')(LeakyRelu2)

    Dropout2 = Dropout(rate)(MaxPool2)
    Conv3 = Conv2D(filters=50, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout2)
    LeakyRelu3 = LeakyReLU(alpha=0.1)(Conv3) 
    MaxPool3 = MaxPooling2D(pool_size=pool_size, padding='same')(LeakyRelu3)

    Dropout3 = Dropout(rate)(MaxPool3)
    Conv4 = Conv2D(filters=50, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout3)
    LeakyRelu4 = LeakyReLU(alpha=0.1)(Conv4) 
    MaxPool4 = MaxPooling2D(pool_size=pool_size, padding='same')(LeakyRelu4)

    Dropout4 = Dropout(rate)(MaxPool4)
    Conv5 = Conv2D(filters=100, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout4)
    LeakyRelu5 = LeakyReLU(alpha=0.1)(Conv5) 
    MaxPool5 = MaxPooling2D(pool_size=pool_size, padding='same')(LeakyRelu5)

    Dropout5 = Dropout(rate)(MaxPool5)
    Conv6 = Conv2D(filters=100, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout5)
    MaxPool6 = MaxPooling2D(pool_size=pool_size, padding='same')(Conv6)

    Dropout6 = Dropout(rate)(MaxPool6)
    Conv7 = Conv2D(filters=100, kernel_size=kernel_size,padding='same', kernel_regularizer=regularizers.l2(reg))(Dropout6)
    MaxPool7 = MaxPooling2D(pool_size=pool_size, padding='same')(Conv7)

    model = Model(inputs=input_layer, outputs=MaxPool7)

    return model

# Define the model for the combination of the previous CNNs and the final CNN for classification

def run_multiview_model(models,inputs):

    merged = concatenate(models)

    Dropout1 = Dropout(rate)(merged)
    Conv_merged1 = Conv2D(filters=100,kernel_size=[2,2],activation='relu',padding='same',input_shape=input_shape)(Dropout1)
    MaxPool_merged1 = MaxPooling2D(pool_size=2,padding='same')(Conv_merged1)

    Dropout2 = Dropout(rate)(MaxPool_merged1)
    Conv_merged2 = Conv2D(filters=50,kernel_size=[2,2],activation='relu',padding='same',input_shape=input_shape)(Dropout2)
    MaxPool_merged2 = MaxPooling2D(pool_size=2,padding='same')(Conv_merged2)

    Dropout3 = Dropout(rate)(MaxPool_merged2)
    Conv_merged3 = Conv2D(filters=80,kernel_size=[2,2],activation='relu',padding='same',input_shape=input_shape)(Dropout3)
    MaxPool_merged3 = MaxPooling2D(pool_size=2,padding='same')(Conv_merged3)

    Dropout31 = Dropout(rate)(MaxPool_merged3)
    Conv_merged31 = Conv2D(filters=140,kernel_size=[2,2],activation='relu',padding='same',input_shape=input_shape)(Dropout31)
    MaxPool_merged31 = MaxPooling2D(pool_size=2,padding='same')(Conv_merged31)

    Flat_merged1 = Flatten()(MaxPool_merged31)
    Dropout4 = Dropout(rate)(Flat_merged1)
    dense_layer_merged1 = Dense(units=100, activation='relu')(Dropout4)

    Dropout6 = Dropout(rate)(dense_layer_merged1)
    dense_layer_merged3 = Dense(units=1, activation='sigmoid')(Dropout6)

    model = Model(inputs=inputs, outputs=dense_layer_merged3)
    return model

# Create four separate CNN models
input_1 = Input(shape=input_shape)
cnn_model_1 = create_cnn_model(input_shape)(input_1)

input_2 = Input(shape=input_shape)
cnn_model_2 = create_cnn_model(input_shape)(input_2)

input_3 = Input(shape=input_shape)
cnn_model_3 = create_cnn_model(input_shape)(input_3)

input_4 = Input(shape=input_shape)
cnn_model_4 = create_cnn_model(input_shape)(input_4)

# include early_stopping here, to see how it changes compared to previous model designs
early_stopping = EarlyStopping(monitor='val_loss', patience=patience)

model_multi = run_multiview_model([cnn_model_1, cnn_model_2, cnn_model_3, cnn_model_4],[input_1, input_2, input_3, input_4])
model_multi.summary()
model_multi.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) 

history = model_multi.fit([train_data[:,i,:,:] for i in range(4)],train_labels,epochs=num_epochs,batch_size=batch_size,validation_data=([test_data[:,i,:,:] for i in range(4)], test_labels), callbacks=[early_stopping])

# Create the filename, which is used for saving the Accuracy and Loss plots and the history files
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_21 (InputLayer)          [(None, 41, 41, 1)]  0           []
#
#  input_23 (InputLayer)          [(None, 41, 41, 1)]  0           []
#
#  input_25 (InputLayer)          [(None, 41, 41, 1)]  0           []
#
#  input_27 (InputLayer)          [(None, 41, 41, 1)]  0           []
#
#  model_8 (Functional)           (None, 1, 1, 100)    843900      ['input_21[0][0]']
#
#  model_9 (Functional)           (None, 1, 1, 100)    843900      ['input_23[0][0]']
#
#  model_10 (Functional)          (None, 1, 1, 100)    843900      ['input_25[0][0]']
#
#  model_11 (Functional)          (None, 1, 1, 100)    843900      ['input_27[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 1, 1, 400)    0           ['model_8[0][0]',
#                                                                   'model_9[0][0]',
#                                                                   'model_10[0][0]',
#                                                                   'model_11[0][0]']
#
#  dropout_108 (Dropout)          (None, 1, 1, 400)    0           ['concatenate_4[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 1, 1, 100)    160100      ['dropout_108[0][0]']
#
#  max_pooling2d_116 (MaxPooling2  (None, 1, 1, 100)   0           ['conv2d_116[0][0]']
#  D)
#
#  dropout_109 (Dropout)          (None, 1, 1, 100)    0           ['max_pooling2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 1, 1, 50)     20050       ['dropout_109[0][0]']
#
#  max_pooling2d_117 (MaxPooling2  (None, 1, 1, 50)    0           ['conv2d_117[0][0]']
#  D)
#
#  dropout_110 (Dropout)          (None, 1, 1, 50)     0           ['max_pooling2d_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 1, 1, 80)     16080       ['dropout_110[0][0]']
#
#  max_pooling2d_118 (MaxPooling2  (None, 1, 1, 80)    0           ['conv2d_118[0][0]']
#  D)
#
#  dropout_111 (Dropout)          (None, 1, 1, 80)     0           ['max_pooling2d_118[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 1, 1, 140)    44940       ['dropout_111[0][0]']
#
#  max_pooling2d_119 (MaxPooling2  (None, 1, 1, 140)   0           ['conv2d_119[0][0]']
#  D)
#
#  flatten_4 (Flatten)            (None, 140)          0           ['max_pooling2d_119[0][0]']
#
#  dropout_112 (Dropout)          (None, 140)          0           ['flatten_4[0][0]']
#
#  dense_12 (Dense)               (None, 100)          14100       ['dropout_112[0][0]']
#
#  dropout_113 (Dropout)          (None, 100)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 1)            101         ['dropout_113[0][0]']
#
# ==================================================================================================
# Total params: 3,630,971
# Trainable params: 3,630,971
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 24/32 [=====================>........] - ETA: 55s - loss: 0.8255 - accuracy: 0.2855
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=104'>105</a> model_multi.summary()
#     <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=105'>106</a> model_multi.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# --> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=107'>108</a> history = model_multi.fit([train_data[:,i,:,:] for i in range(4)],train_labels,epochs=num_epochs,batch_size=batch_size,validation_data=([test_data[:,i,:,:] for i in range(4)], test_labels), callbacks=[early_stopping])
#     <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=109'>110</a> # Create the filename, which is used for saving the Accuracy and Loss plots and the history files
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/HESSML_ENV2/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
